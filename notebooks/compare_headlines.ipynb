# %% [markdown]
# # Find similar news headlines and compare sentiment
# Now that I have done sentiment analysis with headlines and worked with word vectors for article content, I came up with another question: Given a headline, can I look up other similar headlines and compare the sentiment?
# \
# \
# To do this, I use Doc2Vec to vectorize headlines and find other similar headlines. I can then perform sentiment analysis on these headlines using TextBlob.

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
import string
from sklearn.manifold import TSNE
from textblob import TextBlob
import pickle
import json

# %%
with open('../secrets.json') as file:
    secrets = json.load(file)
    connection_string = secrets['connection_string']
db = create_engine(connection_string)
df = pd.read_sql('select * from news_article', con=db)

# %%
df['headline'][0]
# Out:
# 'Top U.S. general resists Trump administration?s efforts to provoke war with Iran ? Mondoweiss'

# %% [markdown]
# ### Function to tokenize headline, remove stop words and remove punctuation

# %%
def clean_headline(headline):
    stop_words = set(stopwords.words('english'))
    return [word for word in nltk.word_tokenize(headline) if word not in stop_words and word not in string.punctuation]

# %% [markdown]
# ### Prepare the data for Doc2Vec

# %%
# LabeledSentence(words=line.split(), labels=['SENT_%s' % uid])
stop_words = set(stopwords.words('english')) 

sentences = []
tag_lookup = {}

# tokenize headlines,remove stop words and punctuation
# Create a dictionary with the tags as keys so I can look up the actual headlines later.
# Also create a list of TaggedDocuments which will be used for training the model.
for i in range(len(df)):
    headline = clean_headline(df['headline'][i])
    tag = f'SENT_{i}'
    sentences.append(TaggedDocument(words=headline, tags=[tag]))
    tag_lookup.update({tag: df['headline'][i]})

sentences
# Out:
# [TaggedDocument(words=['Top', 'U.S.', 'general', 'resists', 'Trump', 'administration', 'efforts', 'provoke', 'war', 'Iran', 'Mondoweiss'], tags=['SENT_0']),
#  TaggedDocument(words=['Atalanta', 'vs', 'Valencia', 'linked', 'accelerating', 'coronavirus', 'spread'], tags=['SENT_1']),
#  TaggedDocument(words=['Boris', 'Johnson', "'s", 'government', 'reportedly', 'furious', 'China', 'believes', 'could', '40', 'times', 'coronavirus', 'cases', 'claims'], tags=['SENT_2']),
#  TaggedDocument(words=['Toyota', 'Gearing', 'Up', 'To', 'Build', 'Ventilators', 'And', 'Face', 'Shields', 'As', 'Mercedes', 'Offers', 'Use', 'Of', '3D', 'Printers'], tags=['SENT_3']),
#  TaggedDocument(words=['Trudeau', 'vows', "'no", 'corners', 'cut', 'accepting', 'masks', 'supplies', 'China'], tags=['SENT_4']),
#  TaggedDocument(words=['Endangered', 'sea', 'turtles', 'hatch', 'Brazil', "'s", 'deserted', 'beaches'], tags=['SENT_5']),
#  TaggedDocument(words=['Edward', 'Snowden', 'says', 'COVID-19', 'could', 'give', 'governments', 'invasive', 'new', 'data-collection', 'powers', 'could', 'last', 'long', 'pandemic'], tags=['SENT_6']),
#  TaggedDocument(words=['UN', 'Environment', 'Chief', 'Warns', 'Nature', 'Sending', 'Us', 'Message', 'Through', 'The', 'Coronavirus', 'Pandemic'], tags=['SENT_7']),
#  TaggedDocument(words=["'So", 'easy', 'I', 'thought', 'fake', 'CRA', '’', 'CERB', 'system', 'gets', 'stellar', 'reviews', 'first', 'days', 'operation'], tags=['SENT_8']),
#  TaggedDocument(words=['Wimbledon', 'paid', 'pandemic', 'insurance', 'almost', '20', 'years', 'Now', '’', 'getting', '141', 'million'], tags=['SENT_9']),
#  TaggedDocument(words=['Pope', 'condemns', 'trying', 'make', 'quick', 'buck', 'coronavirus'], tags=['SENT_10']),
#  TaggedDocument(words=['US', 'intelligence', 'warned', 'November', 'coronavirus', 'spreading', 'China', 'could', "'cataclysmic", 'event', 'report'], tags=['SENT_11']),
#  TaggedDocument(words=['Donald', 'Trump', 'sends', '200', 'ventilators', 'UK', 'London', 'called', 'say', "'needed", 'desperately'], tags=['SENT_12']),
#  TaggedDocument(words=['Iran', '‘', 'hides', '500,000', 'virus', 'cases', '’', 'says', 'member', 'country', '’', 'anti-virus', 'taskforce'], tags=['SENT_13']),
#  TaggedDocument(words=['Are', 'robot'], tags=['SENT_14']),
#  TaggedDocument(words=['Ontario', 'passes', 'emergency', 'order', 'allowing', 'pot', 'shops', 'deliver', 'offer', 'pickup'], tags=['SENT_15']),
#  TaggedDocument(words=['Coronavirus', 'Lack', 'PPE', '‘', 'shocking', 'indictment', '’', 'government', '’', 'handling', 'crisis', 'doctors', '’', 'leaders', 'say'], tags=['SENT_16']),
#  TaggedDocument(words=['5G', 'protesters', 'sabotage', 'Dutch', 'phone', 'towers'], tags=['SENT_17']),
#  TaggedDocument(words=['127', 'European', 'politicians', 'back', 'Taiwan', '’', '...'], tags=['SENT_18']),
#  TaggedDocument(words=['Spain', 'sets', 'back-to-work', 'guidelines', 'coronavirus', 'death', 'rate', 'slows'], tags=['SENT_19']),
#  TaggedDocument(words=['Google', 'banned', 'Zoom', 'app', 'employee', 'computers', '‘', 'security', 'vulnerabilities', '’'], tags=['SENT_20']),
#  TaggedDocument(words=['Taiwan', 'reveals', 'email', 'blasts', 'WHO', 'possible', "'dereliction", 'duty'], tags=['SENT_21']),
#  TaggedDocument(words=['Oldest', 'ever', 'piece', 'string', 'made', 'Neanderthals', '50,000', 'years', 'ago'], tags=['SENT_22']),
#  TaggedDocument(words=['South', 'Korea', 'reports', 'recovered', 'coronavirus', 'patients', 'testing', 'positive'], tags=['SENT_23']),
#  TaggedDocument(words=['WHO', 'warns', 'dangers', 'premature', 'lifting', 'Covid-19', 'restrictions'], tags=['SENT_24']),
#  TaggedDocument(words=['Coronavirus', '10', 'times', 'deadly', 'swine', 'flu', 'says', 'WHO'], tags=['SENT_25']),
#  TaggedDocument(words=["'Everyone", 'wants', 'Rapid', 'COVID-19', 'test', 'kits', 'made', 'Canada', 'approved', 'use'], tags=['SENT_26']),
#  TaggedDocument(words=['Coronavirus', 'closes', 'meat', 'plants', 'Canada', 'United', 'States', 'world', "'s", 'largest', 'pork', 'producer', 'warns', 'shortages'], tags=['SENT_27']),
#  TaggedDocument(words=['Erik', 'Prince', 'Offered', 'Lethal', 'Services', 'Russian', 'Mercenary', 'Firm'], tags=['SENT_28']),
#  TaggedDocument(words=['Brazil', 'likely', '12', 'times', 'coronavirus', 'cases', 'official', 'count', 'study', 'finds'], tags=['SENT_29']),
#  TaggedDocument(words=['Anti-Corbyn', 'Labour', 'officials', 'worked', 'lose', 'general', 'election', 'oust', 'leader', 'leaked', 'dossier', 'finds'], tags=['SENT_30']),
#  TaggedDocument(words=['Iceland', 'finds', 'half', 'citizens', 'coronavirus', 'shown', 'symptoms'], tags=['SENT_31']),
#  TaggedDocument(words=['Universities', 'brace', 'huge', 'losses', 'foreign', 'students', 'drop'], tags=['SENT_32']),
#  TaggedDocument(words=['Coronavirus', 'France', 'extends', 'lockdown', '11', 'May'], tags=['SENT_33']),
#  TaggedDocument(words=['McDonald', "'s", 'apologized', 'restaurant', 'Guangzhou', 'China', 'refused', 'service', 'black', 'customers'], tags=['SENT_34']),
#  TaggedDocument(words=['Scientists', 'Have', 'Reported', 'The', 'First', 'Case', 'Of', 'The', 'Coronavirus', 'Spreading', 'From', 'A', 'Dead', 'Body'], tags=['SENT_35']),
#  TaggedDocument(words=['Growth', 'surveillance', 'may', 'hard', 'scale', 'back', 'pandemic', 'experts', 'say'], tags=['SENT_36']),
#  TaggedDocument(words=['Coronavirus', 'survive', 'long', 'exposure', 'high', 'temperature', 'threat', 'lab', 'staff', 'around', 'world', 'paper'], tags=['SENT_37']),
#  TaggedDocument(words=['Putin', '’', 'Bleak', 'Covid-19', 'Admission', '‘', 'We', 'Don', '’', 'Have', 'Much', 'Brag', 'About', '’'], tags=['SENT_38']),
#  TaggedDocument(words=['Taiwan', 'reports', 'new', 'coronavirus', 'cases', 'first', 'time', 'month'], tags=['SENT_39']),
#  TaggedDocument(words=['The', 'world', 'risks', 'surge', 'measles', 'deaths', '100', 'million', 'children', 'set', 'miss', 'vaccines', 'due', 'coronavirus'], tags=['SENT_40']),
#  TaggedDocument(words=['Coronavirus', 'Older', 'people', "'airbrushed", 'virus', 'figures'], tags=['SENT_41']),
#  TaggedDocument(words=['Exclusive', 'Nurses', 'Mexico', 'hospital', 'hit', 'coronavirus', 'say', 'told', 'avoid', 'masks'], tags=['SENT_42']),
#  TaggedDocument(words=['Amazon', 'fires', 'two', 'employees', 'critical', 'warehouse', 'working', 'conditions'], tags=['SENT_43']),
#  TaggedDocument(words=['A', '99-year-old', 'World', 'War', 'II', 'veteran', 'raises', '2.8', 'million', 'UK', 'health-care', 'workers', 'amid', 'coronavirus'], tags=['SENT_44']),
#  TaggedDocument(words=['Lego', 'producing', '13,000', 'face', 'visors', 'day', 'healthcare', 'workers', 'amid', 'coronavirus', 'pandemic'], tags=['SENT_45']),
#  TaggedDocument(words=['COVID-19', 'Brazilian', 'trial', 'drug', 'touted', 'Trump', 'halted', '11', 'patients', 'die', 'high', 'dose'], tags=['SENT_46']),
#  TaggedDocument(words=['Trump', 'halt', 'WHO', 'funding', 'amid', 'review'], tags=['SENT_47']),
#  TaggedDocument(words=['Coronavirus', 'distancing', 'may', 'need', 'continue', '2022', 'say', 'experts'], tags=['SENT_48']),
#  TaggedDocument(words=['Methane', 'levels', 'all-time', 'high', 'near-record', 'increase', 'gas', '28', 'times', 'potent', 'carbon', 'dioxide'], tags=['SENT_49']),
#  TaggedDocument(words=['Pasta', 'maker', 'Barilla', 'funds', 'cell', 'therapy', 'research', 'coronavirus'], tags=['SENT_50']),
#  TaggedDocument(words=['Poles', 'protest', 'move', 'restrict', 'abortion', 'access'], tags=['SENT_51']),
#  TaggedDocument(words=['IMF', 'says', 'world', "'very", 'likely', 'experience', 'worst', 'recession', 'since', '1930s'], tags=['SENT_52']),
#  TaggedDocument(words=['Small', 'Chloroquine', 'Study', 'Halted', 'Over', 'Risk', 'Fatal', 'Heart', 'Complications'], tags=['SENT_53']),
#  TaggedDocument(words=['French', 'court', 'faults', 'Amazon', 'virus', 'safety', 'limits', 'deliveries'], tags=['SENT_54']),
#  TaggedDocument(words=['Facebook', 'suing', 'Israeli', 'spyware', 'company', 'allegedly', 'hacking', 'WhatsApp', 'Now', 'company', 'says', 'Facebook', 'tried', 'buy', 'spyware', '2017'], tags=['SENT_55']),
#  TaggedDocument(words=['Emergency', 'Declared', 'In', 'Japanese', 'Prefecture', 'Hit', 'By', '2nd', 'Wave', 'Of', 'Coronavirus', 'Infections'], tags=['SENT_56']),
#  TaggedDocument(words=['One', 'third', 'NHS', 'staff', 'tested', 'UK', 'coronavirus'], tags=['SENT_57']),
#  TaggedDocument(words=["'Unacceptable", 'Nigeria', 'condemns', 'treatment', 'citizens', 'China'], tags=['SENT_58']),
#  TaggedDocument(words=['‘', 'There', 'Will', 'Be', 'Mass', 'Starvation', '’', 'Moscow', 'Opposition', 'Warns', 'Mayor', 'Coronavirus', 'Closes', 'Businesses'], tags=['SENT_59']),
#  TaggedDocument(words=['Coronavirus', 'One', 'five', 'deaths', 'linked', 'virus'], tags=['SENT_60']),
#  TaggedDocument(words=['European', 'countries', 'need', 'protect', 'companies', 'Chinese', 'takeovers', 'says', 'EU', 'Commissioner'], tags=['SENT_61']),
#  TaggedDocument(words=['Coronavirus', 'Turkey', 'free', 'thousands', 'convicted', 'criminals', 'keep', 'journalists', 'behind', 'bars'], tags=['SENT_62']),
#  TaggedDocument(words=['Child', 'Sex', 'Abuse', 'Rampant', 'In', 'Pakistan', 'Religious', 'Schools', 'AP', 'Investigation', 'Shows'], tags=['SENT_63']),
#  TaggedDocument(words=['After', 'Putin', "'s", 'bravado', 'COVID-19', 'starting', 'hit', 'Russia', 'hard'], tags=['SENT_64']),
#  TaggedDocument(words=['Fearful', 'virus', 'return', 'Beijing', 'turns', 'virtual', 'fortress'], tags=['SENT_65']),
#  TaggedDocument(words=['Measles', 'resurgence', 'fear', 'amid', 'coronavirus'], tags=['SENT_66']),
#  TaggedDocument(words=["'Great", 'Lockdown', 'rival', 'Great', 'Depression', '3', 'hit', 'global', 'economy', 'says', 'IMF'], tags=['SENT_67']),
#  TaggedDocument(words=['South', 'Korea', 'sending', 'COVID-19', 'test', 'kits', 'U.S'], tags=['SENT_68']),
#  TaggedDocument(words=['Coronavirus', 'vaccine', 'unlikely', 'available', 'within', 'next', '12', 'months', 'says', 'WHO'], tags=['SENT_69']),
#  TaggedDocument(words=['Over', '500,000', 'Zoom', 'accounts', 'sold', 'hacker', 'forums', 'dark', 'web'], tags=['SENT_70']),
#  TaggedDocument(words=['These', 'Videos', 'Show', 'People', 'Burning', 'Down', '5G', 'Cell', 'Phone', 'Towers', 'Over', 'Coronavirus', 'Conspiracy', 'Theories'], tags=['SENT_71']),
#  TaggedDocument(words=['Air', 'quality', 'improves', '40', 'cities', 'took', 'action', 'COVID-19', 'researcher', 'finds'], tags=['SENT_72']),
#  TaggedDocument(words=["'Starve", 'get', 'sick', 'Africa', "'s", 'lockdown', 'dilemma'], tags=['SENT_73']),
#  TaggedDocument(words=['Canada-U.S.', 'border', 'likely', 'remain', 'closed', 'weeks', 'PM', 'says', 'imposing', 'tougher', 'quarantine', 'rules'], tags=['SENT_74']),
#  TaggedDocument(words=['Australia', "'s", 'PM', 'says', "'s", "'unfathomable", 'WHO', 'supports', 'reopening', 'wet', 'markets'], tags=['SENT_75']),
#  TaggedDocument(words=['Rio', 'de', 'Janeiro', 'governor', 'tests', 'positive', 'coronavirus'], tags=['SENT_76']),
#  TaggedDocument(words=['Coronavirus', 'cases', 'Brazil', 'likely', '12', 'times', 'higher', 'reported', 'researchers', 'say'], tags=['SENT_77']),
#  TaggedDocument(words=['COVID-19', 'stopping', "'steady", 'increase', 'Chinese', 'harassment', 'South', 'China', 'Sea'], tags=['SENT_78']),
#  TaggedDocument(words=['French', 'court', 'limits', 'Amazon', 'deliveries', 'essential', 'items', 'amid', 'coronavirus', 'risk'], tags=['SENT_79']),
#  TaggedDocument(words=['Switzerland', 'Coronavirus', '25,936', 'Cases', '1,174', 'Deaths'], tags=['SENT_80']),
#  TaggedDocument(words=['Chinese', 'dams', 'held', 'back', 'Mekong', 'waters', 'drought', 'study', 'finds'], tags=['SENT_81']),
#  TaggedDocument(words=['Second', 'wave', 'locusts', 'east', 'Africa', "'20", 'times', 'worse', 'says', 'UN'], tags=['SENT_82']),
#  TaggedDocument(words=['Growth', 'surveillance', 'may', 'hard', 'scale', 'back', 'pandemic', 'experts', 'say'], tags=['SENT_83']),
#  TaggedDocument(words=['Weird', 'star', 'explosion', 'brightest', 'supernova', 'ever', 'seen'], tags=['SENT_84']),
#  TaggedDocument(words=['Kazakhstan', 'summons', 'Chinese', 'ambassador', 'protest', 'article'], tags=['SENT_85']),
#  TaggedDocument(words=['Amazon', 'slashes', 'commission', 'rates', 'program', 'gives', 'publishers', 'cut', 'sales'], tags=['SENT_86']),
#  TaggedDocument(words=['Toronto', 'Loblaws', 'mistakenly', 'left', 'open', 'Easter', 'Sunday'], tags=['SENT_87']),
#  TaggedDocument(words=['China', 'Is', 'Censoring', 'Research', 'COVID-19', 'Origins', 'Deleted', 'Web', 'Page', 'Suggests'], tags=['SENT_88']),
#  TaggedDocument(words=['GM', 'begins', 'production', 'ventilators', 'U.S.', 'government'], tags=['SENT_89']),
#  TaggedDocument(words=['China', '’', 'bid', 'repair', 'coronavirus-hit', 'image', 'backfiring', 'West'], tags=['SENT_90']),
#  TaggedDocument(words=['UK', 'coronavirus', 'death', 'toll', 'could', 'far', 'higher', 'previously', 'shown'], tags=['SENT_91']),
#  TaggedDocument(words=['Mask', 'donation', 'Taiwan', 'reaches', 'United', 'Kingdom'], tags=['SENT_92']),
#  TaggedDocument(words=['Coronavirus', 'updates', 'U.S.', 'death', 'toll', 'tops', '25,000'], tags=['SENT_93']),
#  TaggedDocument(words=['Covid', '19', 'Tracker', 'India', 'State-Wise', 'Narandra', 'Modi', 'speech'], tags=['SENT_94']),
#  TaggedDocument(words=['France', "'s", 'rate', 'coronavirus', 'infections', 'deaths', 'accelerating'], tags=['SENT_95']),
#  TaggedDocument(words=['Good', 'news', 'Taiwan', 'reports', 'zero', 'new', 'coronaviru', '...'], tags=['SENT_96']),
#  TaggedDocument(words=['War', 'veteran', '99', 'raises', '2.5m', 'NHS', 'amid', 'pandemic'], tags=['SENT_97']),
#  TaggedDocument(words=['Germany', 'calls', 'migrant', 'medics', 'help', 'tackle', 'coronavirus'], tags=['SENT_98']),
#  TaggedDocument(words=['Saudi', 'security', "'kill", 'tribal', 'activist', 'resisted', 'deportation'], tags=['SENT_99']),
#  TaggedDocument(words=['Canada', 'still', 'weeks', 'away', 'easing', 'pandemic', 'restrictions', 'restarting', 'economy', 'Trudeau', 'says'], tags=['SENT_100']),
#  TaggedDocument(words=['Taiwan', '’', 'coronavirus', 'December', 'warning', 'WHO', 'person-to-person', 'spreading', 'went', 'unheeded', 'bombshell', 'email', 'reveals', '–', 'The', 'Sun'], tags=['SENT_101']),
#  TaggedDocument(words=['Deforestation', 'Spikes', 'Amazon', 'Amid', 'Coronavirus', 'Crisis'], tags=['SENT_102']),
#  TaggedDocument(words=['Coronavirus', 'Ireland', '5G', 'arsonists', 'target', 'mobile', 'masts', 'conspiracy', 'theories', 'start', 'take', 'toll'], tags=['SENT_103']),
#  TaggedDocument(words=['Historic', 'Oil', 'Deal', 'Proves', 'Insufficient', 'Increase', 'Oil', 'Prices'], tags=['SENT_104']),
#  TaggedDocument(words=['Tour', 'de', 'France', '2020', 'delayed', 'organisers', 'say', 'impossible', 'start', 'planned', 'amid', 'coronavirus', 'pandemic'], tags=['SENT_105']),
#  TaggedDocument(words=['UK', 'coronavirus', 'death', 'toll', 'could', 'far', 'higher', 'previously', 'shown'], tags=['SENT_106']),
#  TaggedDocument(words=['Trump', 'slams', 'WHO', 'coronavirus', 'response', 'suspends', 'US', 'payments'], tags=['SENT_107']),
#  TaggedDocument(words=['Coronavirus', 'crisis', 'could', 'plunge', 'half', 'billion', 'people', 'poverty'], tags=['SENT_108']),
#  TaggedDocument(words=['Calls', 'loosen', 'US', 'sanctions', 'Cuba', 'battles', 'pandemic'], tags=['SENT_109']),
#  TaggedDocument(words=['Two', 'Brazilian', 'governors', 'test', 'positive', 'coronavirus'], tags=['SENT_110']),
#  TaggedDocument(words=['Coronavirus', 'UK', 'made', 'promises', 'China', 'would', 'refer', 'COVID-19', 'China', 'claims'], tags=['SENT_111']),
#  TaggedDocument(words=['Trump', 'halt', 'WHO', 'funding', 'amid', 'review'], tags=['SENT_112']),
#  TaggedDocument(words=['Wagga', 'City', 'Council', 'cuts', 'ties', 'Chinese', 'sister', 'city', 'Kunming'], tags=['SENT_113']),
#  TaggedDocument(words=['Beijing', "'s", 'pandemic', 'response', 'China', "'s", "'Chornobyl", 'moment', 'critics', 'say'], tags=['SENT_114']),
#  TaggedDocument(words=['Paris', 'climate', 'goals', 'failure', "'could", 'cost', 'world', '600', 'tn'], tags=['SENT_115']),
#  TaggedDocument(words=['China', 'Limited', 'Mekong', '’', 'Flow', 'Other', 'Countries', 'Suffered', 'Drought'], tags=['SENT_116']),
#  TaggedDocument(words=['Mort', 'Drucker', 'legendary', 'caricaturist', 'Mad', 'Magazine', '50', 'years', 'dies', '91'], tags=['SENT_117']),
#  TaggedDocument(words=['UK', 'urged', 'stop', 'China', 'taking', 'control', 'Imagination', 'Tech', 'lawmaker'], tags=['SENT_118']),
#  TaggedDocument(words=['Italians', 'Offered', 'Cash', 'Film', '‘', 'Thank', 'You', 'Russia', '’', 'Videos', 'Coronavirus', 'Aid', '–', 'Reports'], tags=['SENT_119']),
#  TaggedDocument(words=['Coronavirus', 'mutation', 'could', 'threaten', 'race', 'develop', 'vaccine'], tags=['SENT_120']),
#  TaggedDocument(words=['Italy', 'records', 'fewest', 'new', 'coronavirus', 'cases', 'month'], tags=['SENT_121']),
#  TaggedDocument(words=['Scientists', 'say', 'social', 'distancing', 'may', 'need', 'stretch', '2022', 'research', 'immunity', 'needed'], tags=['SENT_122']),
#  TaggedDocument(words=['US', 'officials', 'reportedly', 'concerned', 'safety', 'breaches', 'Wuhan', 'lab', 'studying', 'coronaviruses', 'bats', 'could', 'cause', 'pandemic'], tags=['SENT_123']),
#  TaggedDocument(words=['Set', 'Fire', 'Husband', 'Iraqi', 'Victim', 'Sparks', 'Social', 'Media', 'Calls', 'Women', "'s", 'Protection'], tags=['SENT_124']),
#  TaggedDocument(words=['Climate', 'crisis', 'UK', 'aid', 'money', 'funnelled', 'fossil', 'fuel', 'companies'], tags=['SENT_125']),
#  TaggedDocument(words=['Paris', 'climate', 'goals', 'failure', "'could", 'cost', 'world', '600', 'tn'], tags=['SENT_126']),
#  TaggedDocument(words=['Thousands', 'Defy', 'Lockdown', 'At', 'Bandra', 'Station', 'In', 'Mumbai', 'Lathicharged', 'By', 'Cops'], tags=['SENT_127']),
#  TaggedDocument(words=['Untraceable', 'cases', 'Japan', 'raise', 'fear', 'outbreak', 'spiraling', 'control'], tags=['SENT_128']),
#  TaggedDocument(words=['‘', 'Cough', 'chamber', '’', 'shows', '2', 'metres', 'physical', 'distancing', 'enough', 'Western', 'University', 'researchers'], tags=['SENT_129']),
#  TaggedDocument(words=['France', 'summons', 'Chinese', 'envoy', 'comments', 'coronavirus', 'handling'], tags=['SENT_130']),
#  TaggedDocument(words=["'Bigger", 'winning', 'war', 'WWII', 'vet', 'aged', '99', 'survives', 'coronavirus', 'Brazil'], tags=['SENT_131']),
#  TaggedDocument(words=['Armed', 'men', 'seize', 'release', 'tanker', 'Iran', 'Strait', 'Hormuz'], tags=['SENT_132']),
#  TaggedDocument(words=['Zimbabwe', 'president', 'threatens', 'fake', 'news', 'author', '20', 'years', 'jail'], tags=['SENT_133']),
#  TaggedDocument(words=['Amazon', 'ordered', 'limit', 'French', 'trade', 'essential', 'goods'], tags=['SENT_134']),
#  TaggedDocument(words=['Taiwan', 'records', 'new', 'COVID-19', 'cases', 'total', 'kept', '393'], tags=['SENT_135']),
#  TaggedDocument(words=['Coronavirus', "'World", 'faces', 'worst', 'recession', 'since', 'Great', 'Depression'], tags=['SENT_136']),
#  TaggedDocument(words=['Paris', 'climate', 'goals', 'failure', "'could", 'cost', 'world', '600', 'tn'], tags=['SENT_137']),
#  TaggedDocument(words=['Coronavirus', "'World", 'faces', 'worst', 'recession', 'since', 'Great', 'Depression'], tags=['SENT_138']),
#  TaggedDocument(words=['Britain', "'s", 'ITV', 'fire', 'presenter', "'s", '5G-coronavirus', 'comments'], tags=['SENT_139']),
#  TaggedDocument(words=['Taiwan', 'Reports', 'No', 'New', 'Coronavirus', 'Cases', 'Adding', 'To', 'Success', 'In', 'Fighting', 'Pandemic'], tags=['SENT_140']),
#  TaggedDocument(words=['Ukrainian', 'officials', 'Fires', 'near', 'Chernobyl', 'nuclear', 'plant'], tags=['SENT_141']),
#  TaggedDocument(words=['Russia', 'says', "'s", 'ready', 'hypersonic', 'missile', 'talks', 'U.S'], tags=['SENT_142']),
#  TaggedDocument(words=['Deadly', 'olive', 'tree', 'disease', 'across', 'Europe', "'could", 'cost', 'billions'], tags=['SENT_143']),
#  TaggedDocument(words=['Wet', 'markets', 'selling', 'wildlife', '–', 'birds', 'monkeys', 'bats', '–', 'go', 'quiet', 'Indonesia', 'amid', 'coronavirus', 'pandemic'], tags=['SENT_144']),
#  TaggedDocument(words=['Coronavirus', 'WHO', 'urges', 'China', 'close', '‘', 'dangerous', '’', 'wet', 'market', 'stalls', 'Wuhan', 'begin', 'reopen'], tags=['SENT_145']),
#  TaggedDocument(words=['Egyptian', 'police', 'kill', '7', 'terrorists', 'raid', 'Cairo', '’', 'El-Amiriya', 'ahead', 'Easter'], tags=['SENT_146']),
#  TaggedDocument(words=['Chernobyl', 'fire', 'control', 'Ukraine', 'officials', 'say'], tags=['SENT_147']),
#  TaggedDocument(words=['Coronavirus', 'takes', 'serious', 'turn', 'Russia', 'Putin', 'longer', 'radiates', 'confidence'], tags=['SENT_148']),
#  TaggedDocument(words=['Coronavirus', 'India', 'makes', 'face', 'masks', 'mandatory', '300m', 'people', 'punishable', 'six', 'months', 'prison'], tags=['SENT_149']),
#  TaggedDocument(words=['Global', 'economy', 'suffer', 'worst', 'year', 'since', 'Great', 'Depression', '1930s', 'IMF', 'says'], tags=['SENT_150']),
#  TaggedDocument(words=['Chinese', 'ship', 'back', 'Viet', 'waters', 'region', 'tackles', 'coronavirus'], tags=['SENT_151']),
#  TaggedDocument(words=['UK', 'coronavirus', 'hospital', 'death', 'toll', 'rises', '11,329'], tags=['SENT_152']),
#  TaggedDocument(words=['Daily', 'Telegraph', 'stops', 'publishing', 'section', 'paid', 'China'], tags=['SENT_153']),
#  TaggedDocument(words=['Forest', 'fires', 'near', 'Chernobyl', 'nuclear', 'plant', 'Ukrainian', 'officials', 'say'], tags=['SENT_154']),
#  TaggedDocument(words=['Coronavirus', 'Patients', 'suffered', 'strokes', 'neurological', 'symptoms', 'says', 'study'], tags=['SENT_155']),
#  TaggedDocument(words=['Coronavirus', 'Fears', 'threatened', 'sun', 'bear', 'China', 'touts', 'injecting', 'bear', 'bile', 'fight', 'virus'], tags=['SENT_156']),
#  TaggedDocument(words=['UK', 'coronavirus', 'death', 'toll', 'could', 'far', 'higher', 'previously', 'shown'], tags=['SENT_157']),
#  TaggedDocument(words=['Outrage', '‘', 'anti-lockdown', 'conspiracy', 'theorists', 'ignore', 'coronavirus', 'fears', 'stage', 'public', 'protest', 'Vancouver', '’'], tags=['SENT_158']),
#  TaggedDocument(words=['HMO', '’', 'work', 'Chinese', 'firm', 'virus', 'tests', 'DNA', 'privacy', 'fears', '—', 'report'], tags=['SENT_159']),
#  TaggedDocument(words=['Obesity', 'major', 'COVID-19', 'risk', 'factor', 'says', 'French', 'chief', 'epidemiologist'], tags=['SENT_160']),
#  TaggedDocument(words=['Luxembourg', 'blocks', 'US', 'bid', '1.6', 'billion', '9/11', 'compensation', 'Iran'], tags=['SENT_161']),
#  TaggedDocument(words=['Police', 'foil', '€15m', 'plan', 'sell', 'Germany', 'fake', 'face', 'masks'], tags=['SENT_162']),
#  TaggedDocument(words=['Police', 'investigating', 'George', 'Pell', 'fresh', 'child', 'sexual', 'abuse', 'allegation', '–', 'report'], tags=['SENT_163']),
#  TaggedDocument(words=['China', 'using', 'coronavirus', 'cover', 'seize', 'control', 'UK', "'s", 'Imagination', 'Technologies'], tags=['SENT_164']),
#  TaggedDocument(words=['What', 'When', 'Will', 'Open', 'Czech', 'Republic'], tags=['SENT_165']),
#  TaggedDocument(words=['Two', 'Brazilian', 'governors', 'test', 'positive', 'coronavirus'], tags=['SENT_166']),
#  TaggedDocument(words=['Coronavirus', 'Police', 'collect', 'nearly', '800', 'bodies', 'homes', 'Ecuador', "'s", 'virus', 'epicenter'], tags=['SENT_167']),
#  TaggedDocument(words=['Trump', 'halts', 'World', 'Health', 'Organization', 'funding', 'handling', 'coronavirus'], tags=['SENT_168']),
#  TaggedDocument(words=['Iran', '1.6', 'Billion', 'Released', 'Luxembourg', 'Go', 'Coronavirus'], tags=['SENT_169']),
#  TaggedDocument(words=['Iraq', 'suspends', 'Reuters', 'three', 'months', 'report', 'coronavirus', 'cases'], tags=['SENT_170']),
#  TaggedDocument(words=['China', 'denies', 'city', 'discriminating', "'African", 'brothers'], tags=['SENT_171']),
#  TaggedDocument(words=['Coronavirus', 'China', '’', 'unemployment', 'crisis', 'mounts', 'nobody', 'knows', 'true', 'number', 'jobless'], tags=['SENT_172']),
#  TaggedDocument(words=['Cede', 'empresa', 'extranjera', 'venderá', 'ventiladores', 'BC', 'para', 'atender', 'covid-19'], tags=['SENT_173']),
#  TaggedDocument(words=['Trump', 'says', '``', 'authorizing', "''", 'governors', 'reopen', 'states'], tags=['SENT_174']),
#  TaggedDocument(words=['Hong', 'Kong', 'judges', 'battle', 'Beijing', 'rule', 'law', 'virus', 'halts', 'protests'], tags=['SENT_175']),
#  TaggedDocument(words=['Kazakhstan', 'summons', 'Chinese', 'ambassador', 'protest', 'article'], tags=['SENT_176']),
#  TaggedDocument(words=['Sri', 'Lanka', 'Cremates', 'Muslim', 'Coronavirus', 'Victims', 'Cites', 'High', 'Groundwater', 'Level', 'In', 'The', 'Island', 'Nation'], tags=['SENT_177']),
#  TaggedDocument(words=['PA', 'rebuffs', 'call', 'stop', '‘', 'incitement', '’', 'campaign', 'blaming', 'Israel', 'virus', 'cases'], tags=['SENT_178']),
#  TaggedDocument(words=['South', 'American', 'indigenous', 'peoples', 'close', 'territories', 'response', 'COVID-19'], tags=['SENT_179']),
#  TaggedDocument(words=['Chinese', 'dams', 'held', 'back', 'Mekong', 'waters', 'drought', 'study', 'finds', 'Tuoi', 'Tre', 'News'], tags=['SENT_180']),
#  TaggedDocument(words=['Taiwan', 'reports', 'new', 'COVID-19', 'cases', 'first', 'time', 'month'], tags=['SENT_181']),
#  TaggedDocument(words=['Indian', 'banks', 'issue', 'gag', 'orders', 'employees', 'branch', 'overcrowding', 'documents', 'sources'], tags=['SENT_182']),
#  TaggedDocument(words=['Coronavirus', 'Nicola', 'Sturgeon', 'investigate', '‘', 'unacceptable', '’', 'claims', 'PPE', 'withheld', 'England'], tags=['SENT_183']),
#  TaggedDocument(words=['How', 'China', 'Deceived', 'WHO'], tags=['SENT_184']),
#  TaggedDocument(words=['Coronavirus', 'Austria', 'Italy', 'reopen', 'shops', 'lockdown', 'eased'], tags=['SENT_185']),
#  TaggedDocument(words=['Singapore', 'Taiwan', 'And', 'Hong', 'Kong', 'Seemed', 'To', 'Have', 'Beaten', 'Coronavirus', 'But', 'Then', 'Cases', 'Spiked'], tags=['SENT_186']),
#  TaggedDocument(words=['Coronavirus', 'global', 'economic', 'downturn', '2020', 'likely', 'worst', 'since', 'Great', 'Depression', 'IMF', 'says'], tags=['SENT_187']),
#  TaggedDocument(words=['IMF', 'Coronavirus', 'effect', 'drive', 'global', 'economy', 'worst', 'year', 'since', 'Great', 'Depression'], tags=['SENT_188']),
#  TaggedDocument(words=['Hundreds', 'thousands', 'return', 'work', 'Spain', 'relaxes', 'coronavirus', 'lockdown'], tags=['SENT_189']),
#  TaggedDocument(words=['Pandemic', 'causing', 'deep', 'recession', 'could', 'get', 'worse', 'IMF'], tags=['SENT_190']),
#  TaggedDocument(words=['Exxon', 'raises', '9.5', 'billion', 'load', 'cash', 'debt', 'market', 'still', 'open', 'new', 'deals'], tags=['SENT_191']),
#  TaggedDocument(words=['Chernobyl', 'Forest', 'fire', 'around', 'defunct', 'nuclear', 'plant', 'put', 'Ukraine', 'govt'], tags=['SENT_192']),
#  TaggedDocument(words=['Locked', 'violent', 'partner', 'domestic', 'violence', 'soars', 'Poland', 'coronavirus', 'pandemic'], tags=['SENT_193']),
#  TaggedDocument(words=['Cruel', 'Bear', 'Bile', 'Industry', 'Thrives', 'Despite', 'Pandemic', 'Risks', 'Guelph', 'Ontario', 'World', 'View', 'News', 'Guelph', 'Now'], tags=['SENT_194']),
#  TaggedDocument(words=['3rd', 'environmental', 'activist', 'killed', 'year', 'Mexico'], tags=['SENT_195']),
#  TaggedDocument(words=['Coronavirus', 'Labour', 'official', 'spread', 'conspiracy', 'theory', 'Boris', 'Johnson', 'Covid-19'], tags=['SENT_196']),
#  TaggedDocument(words=['Coronavirus', "'World", 'faces', 'worst', 'recession', 'since', 'Great', 'Depression'], tags=['SENT_197']),
#  TaggedDocument(words=['Shelling', 'across', 'Pakistan-India', 'border', 'kills', 'three'], tags=['SENT_198']),
#  TaggedDocument(words=['UK', 'cases', 'domestic', 'abuse', 'female', 'family', 'members', 'double'], tags=['SENT_199']),
#  TaggedDocument(words=['Trudeau', 'warns', 'Canada', "'s", 'coronavirus', 'shutdown', 'likely', 'remain', 'weeks'], tags=['SENT_200']),
#  TaggedDocument(words=['Coronavirus', '20', 'suspected', 'phone', 'mast', 'attacks', 'Easter'], tags=['SENT_201']),
#  TaggedDocument(words=['Many', 'hotels', 'could', 'remain', 'closed', 'good', 'Ottawa', 'hotelier', 'says'], tags=['SENT_202']),
#  TaggedDocument(words=['Opt', 'Chinese', 'servers', 'Zoom', 'April', '18'], tags=['SENT_203']),
#  TaggedDocument(words=['China', '’', 'initial', 'coronavirus', 'outbreak', 'Wuhan', 'spread', 'twice', 'fast', 'thought', 'new', 'study', 'suggests'], tags=['SENT_204']),
#  TaggedDocument(words=['Bolsonaro', 'Could', 'Decide', 'Isolation', 'Says', 'Prosecutor', 'General'], tags=['SENT_205']),
#  TaggedDocument(words=['Dutch', 'growers', 'destroy', 'millions', 'tulips', 'coronavirus', 'slams', 'sales'], tags=['SENT_206']),
#  TaggedDocument(words=['UK', 'Prime', 'Minister', 'Boris', 'Johnson', 'tested', 'negative', 'coronavirus', 'hospital', 'release'], tags=['SENT_207']),
#  TaggedDocument(words=['Virus', 'Covid-19', 'conspiracy', 'theories', 'spreads', 'Ireland'], tags=['SENT_208']),
#  TaggedDocument(words=['Coronavirus', 'German', 'zoo', 'may', 'feed', 'animals'], tags=['SENT_209']),
#  TaggedDocument(words=['Chinese', 'ship', 'returns', 'waters', 'Vietnam', 'amid', 'virus', "'distraction", 'charges'], tags=['SENT_210']),
#  TaggedDocument(words=['China-Thailand', 'coronavirus', 'social', 'media', 'war', 'escalates'], tags=['SENT_211']),
#  TaggedDocument(words=['Trudeau', 'fire', 'Easter', 'trip', 'despite', 'urging', 'Canadians', '‘', 'sacrifice', '’', 'plans'], tags=['SENT_212']),
#  TaggedDocument(words=['Germany', 'set', 'consider', 'relaxing', 'coronavirus', 'restrictions'], tags=['SENT_213']),
#  TaggedDocument(words=['Gaza', 'arrests', 'Zoom', 'chat', 'Israelis', 'spark', "'normalization", 'row'], tags=['SENT_214']),
#  TaggedDocument(words=['Tokyo', '‘', 'Plan', 'B', '’', 'another', 'Olympic', 'postponement'], tags=['SENT_215']),
#  TaggedDocument(words=['Coronavirus', 'aid', 'Italy', 'says', '39', 'billion', 'EU'], tags=['SENT_216']),
#  TaggedDocument(words=['Saudi', 'security', "'kill", 'tribal', 'activist', 'resisted', 'deportation'], tags=['SENT_217']),
#  TaggedDocument(words=['In', 'Mexico', 'City', 'Government', 'Delivers', 'Medical', 'Supplies', 'COVID-19', 'Patients', '’', 'Homes'], tags=['SENT_218']),
#  TaggedDocument(words=['Coronavirus', 'Donald', 'Trump', 'pulls', 'US', 'funding', 'World', 'Health', 'Organisation'], tags=['SENT_219']),
#  TaggedDocument(words=['Coronavirus', 'Police', 'bust', 'massive', 'face', 'mask', 'scam'], tags=['SENT_220']),
#  TaggedDocument(words=['India', 'extends', 'world', "'s", 'biggest', 'virus', 'lockdown'], tags=['SENT_221']),
#  TaggedDocument(words=['Child', 'sex', 'abuse', 'Pakistan', "'s", 'religious', 'schools', 'endemic'], tags=['SENT_222']),
#  TaggedDocument(words=['Myanmar', 'Pastors', 'Face', 'Prosecution', 'Defying', 'Ban', 'Religious', 'Gatherings', 'Amid', 'COVID-19'], tags=['SENT_223']),
#  TaggedDocument(words=['Coronavirus', 'Britons', 'advised', 'challenge', 'neighbours', 'lockdown', 'breaches', 'rather', 'calling', 'police'], tags=['SENT_224']),
#  TaggedDocument(words=['Twitter', 'restores', 'account', 'Chinese', 'embassy', 'Sri', 'Lanka', 'demands', 'freedom', 'speech'], tags=['SENT_225']),
#  TaggedDocument(words=['2', 'world', "'s", 'biggest', 'drugmakers', 'teamed', 'coronavirus', 'vaccine', "'re", 'aiming', 'launch', 'next', 'year'], tags=['SENT_226']),
#  TaggedDocument(words=['White-tailed', 'eagles', 'spotted', 'England', 'first', 'time', '240', 'years'], tags=['SENT_227']),
#  TaggedDocument(words=['Air', 'France', 'talks', 'French', 'govt', 'emergency', 'funding', 'Les', 'Echos'], tags=['SENT_228']),
#  TaggedDocument(words=['UK', 'coronavirus', 'death', 'toll', 'could', 'far', 'higher', 'previously', 'shown'], tags=['SENT_229']),
#  TaggedDocument(words=['Right', 'Wing', 'Politicians', 'And', 'Media', 'Are', 'Calling', 'For', 'China', 'To', 'Pay', '``', 'Reparations', "''", 'For', 'The', 'Coronavirus'], tags=['SENT_230']),
#  TaggedDocument(words=['Coronavirus', 'US', 'halt', 'funding', 'WHO', 'says', 'Trump'], tags=['SENT_231']),
#  TaggedDocument(words=['Kazakhstan', 'summons', 'Chinese', 'ambassador', 'protest', 'article'], tags=['SENT_232']),
#  TaggedDocument(words=['Mexico', 'No', 'secret', 'side', 'deal', 'US', 'help', 'OPEC', 'agreement'], tags=['SENT_233']),
#  TaggedDocument(words=['Coronavirus', 'death', 'toll', '‘', 'airbrushing', '’', 'older', 'people', 'dying', 'care', 'system'], tags=['SENT_234']),
#  TaggedDocument(words=['Olive', 'oil', 'industry', 'increasing', 'threat', "'olive", 'leprosy'], tags=['SENT_235']),
#  TaggedDocument(words=['Imagination', 'Technologies', 'grilled', 'China', 'security', 'issues'], tags=['SENT_236']),
#  TaggedDocument(words=['Coronavirus', 'WHO', 'says', '70', 'vaccines', 'works', 'three', 'leading', 'candidates'], tags=['SENT_237']),
#  TaggedDocument(words=['Animal', 'Crossing', 'game', 'removed', 'sale', 'China', 'Hong', 'Kong', 'democracy', 'messages'], tags=['SENT_238']),
#  TaggedDocument(words=['During', 'coronavirus', 'pandemic', '‘', 'fake', 'news', '’', 'putting', 'lives', 'risk', 'UNESCO'], tags=['SENT_239']),
#  TaggedDocument(words=['2020', 'could', 'warmest', 'year', 'record'], tags=['SENT_240']),
#  TaggedDocument(words=['Chernobyl', 'fire', 'Huge', 'forest', 'blaze', 'moves', 'within', 'one', 'kilometre', 'abandoned', 'nuclear', 'plant'], tags=['SENT_241']),
#  TaggedDocument(words=['Denmark', 'proposes', 'faster', 'easing', 'lockdown', 'coronavirus', 'cases', 'fall', 'PM'], tags=['SENT_242']),
#  TaggedDocument(words=['Scientists', 'built', "'cough", 'chamber', 'see', 'far', 'droplets', 'actually', 'travel'], tags=['SENT_243']),
#  TaggedDocument(words=['Wildfires', "'edge", 'closer', 'Chernobyl', 'nuclear', 'plant'], tags=['SENT_244']),
#  TaggedDocument(words=['Coronavirus', 'lockdowns', 'could', 'end', 'months', 'Australians', 'willing', 'movements', 'monitored'], tags=['SENT_245']),
#  TaggedDocument(words=['Nearly', '45', 'COVID-19', 'cases', 'Ontario', 'considered', 'resolved'], tags=['SENT_246']),
#  TaggedDocument(words=['Coronavirus', 'One', 'seven', 'pregnant', 'women', 'test', 'positive', 'Covid-19', 'study', 'reveals'], tags=['SENT_247']),
#  TaggedDocument(words=["'They", 'brave', 'Briton', '99', 'raises', 'millions', 'health', 'workers'], tags=['SENT_248']),
#  TaggedDocument(words=['Coronavirus', 'German', 'zoo', 'may', 'feed', 'animals'], tags=['SENT_249']),
#  TaggedDocument(words=['World', 'Bank', 'sees', "'huge", 'willingness', 'suspend', 'debt', 'payments', 'poorest', 'countries'], tags=['SENT_250']),
#  TaggedDocument(words=['Good', 'news', 'Taiwan', 'reports', 'zero', 'new', 'coronaviru', '...'], tags=['SENT_251']),
#  TaggedDocument(words=['Singapore', 'Japan', 'cases', 'jump', 'India', 'extends', 'largest', 'lockdown'], tags=['SENT_252']),
#  TaggedDocument(words=['UK', 'urged', 'stop', 'China', 'taking', 'control', 'Imagination', 'Tech', 'lawmaker'], tags=['SENT_253']),
#  TaggedDocument(words=['Covid', '19', 'coronavirus', 'Mutation', 'threatens', 'race', 'develop', 'vaccine'], tags=['SENT_254']),
#  TaggedDocument(words=['Pandemic', 'exposing', "'cracks", 'financial', 'system', 'bank', 'losses', 'likely', 'IMF'], tags=['SENT_255']),
#  TaggedDocument(words=['USFDA', 'clears', 'four', 'Indian', 'manufacturing', 'plants', '10', 'days'], tags=['SENT_256']),
#  TaggedDocument(words=['Coronavirus', 'Suppliers', "'not", 'asked', 'divert', 'PPE', 'England'], tags=['SENT_257']),
#  TaggedDocument(words=['Exclusive', 'France', 'hike', 'crisis', 'response', '10', 'billion', 'euros', '110', 'billion', 'sources'], tags=['SENT_258']),
#  TaggedDocument(words=['Arabic', 'press', 'review', 'Al', 'Jazeera', 'host', 'receives', 'death', 'threats', 'Saudi', 'criticism'], tags=['SENT_259']),
#  TaggedDocument(words=['Coronavirus', "'World", 'faces', 'worst', 'recession', 'since', 'Great', 'Depression'], tags=['SENT_260']),
#  TaggedDocument(words=['Global', 'economy', '2020', 'track', 'sharpest', 'downturn', 'since', '1930s', 'IMF'], tags=['SENT_261']),
#  TaggedDocument(words=['Scientists', 'create', 'mutant', 'enzyme', 'recycles', 'plastic', 'bottles', 'hours'], tags=['SENT_262']),
#  TaggedDocument(words=['Man', 'accidentally', 'ejects', 'fighter', 'jet', 'surprise', 'flight'], tags=['SENT_263']),
#  TaggedDocument(words=['Coronavirus', 'Around', 'half', 'COVID-19', 'deaths', 'care', 'homes'], tags=['SENT_264']),
#  TaggedDocument(words=['Thousands', 'Defy', 'Lockdown', 'At', 'Bandra', 'Station', 'In', 'Mumbai', 'Lathicharged', 'By', 'Cops'], tags=['SENT_265']),
#  TaggedDocument(words=['Austria', 'reopens', 'thousands', 'shops', 'first', 'loosening', 'coronavirus', 'lockdown'], tags=['SENT_266']),
#  TaggedDocument(words=['Special', 'Report', 'Hong', 'Kong', 'judges', 'battle', 'Beijing', 'rule', 'law', 'pandemic', 'chills', 'protests'], tags=['SENT_267']),
#  TaggedDocument(words=['SPECIAL', 'REPORT-Hong', 'Kong', 'judges', 'battle', 'Beijing', 'rule', 'law', 'pandemic', 'chills', 'protests'], tags=['SENT_268']),
#  TaggedDocument(words=['World', '‘', 'certainly', 'seeing', 'peak', '’', 'Covid-19', 'yet', 'says', 'WHO'], tags=['SENT_269']),
#  TaggedDocument(words=['Mafia-linked', 'funeral', 'investigated', 'amid', 'coronavirus', 'lockdown'], tags=['SENT_270']),
#  TaggedDocument(words=['UK', 'pledges', '250', 'million', 'WHO', 'charities', 'help', 'slow', 'spread', 'coronavirus'], tags=['SENT_271']),
#  TaggedDocument(words=['China', 'moves', 'block', 'new', 'virus', 'flare-up', 'Russian', 'border'], tags=['SENT_272']),
#  TaggedDocument(words=['MPs', 'summon', 'China-owned', 'firm', 'execs', 'security', 'concerns'], tags=['SENT_273']),
#  TaggedDocument(words=['WHO', 'officials', 'say', "'s", 'unclear', 'whether', 'recovered', 'coronavirus', 'patients', 'immune', 'second', 'infection'], tags=['SENT_274']),
#  TaggedDocument(words=['Apple', 'launches', 'site', 'show', 'coronavirus', 'lockdowns', 'affect', 'movement'], tags=['SENT_275']),
#  TaggedDocument(words=['Exclusive', 'Nurses', 'Mexico', 'hospital', 'hit', 'coronavirus', 'say', 'told', 'avoid', 'masks'], tags=['SENT_276']),
#  TaggedDocument(words=['Arsonists', 'attack', 'phone', 'mast', 'serving', 'NHS', 'Nightingale', 'hospital'], tags=['SENT_277']),
#  TaggedDocument(words=['Oil', 'gains', 'U.S.', 'shale', 'production', 'set', 'fall', 'sharply'], tags=['SENT_278']),
#  TaggedDocument(words=['Iran', 'coronavirus', 'fatalities', 'drop', 'double', 'figures', 'first', 'time', 'month'], tags=['SENT_279']),
#  TaggedDocument(words=['Australian', 'cardinal', 'links', 'corruption', 'child', 'abuse', 'charges'], tags=['SENT_280']),
#  TaggedDocument(words=['India', 'requests', 'US', 'extend', 'H1B', 'visas', 'stranded', 'Indians', 'amid', 'COVID-19', 'pandemic'], tags=['SENT_281']),
#  TaggedDocument(words=['Taiwan', 'reports', 'new', 'coronavirus', 'cases', 'first', 'time', 'month'], tags=['SENT_282']),
#  TaggedDocument(words=['Man', 'carrying', 'weapons', 'amid', 'police', 'lockdown', 'Hong', 'Kong', 'Polytechnic', 'University', 'sentenced', '10', 'months', '’', 'jail'], tags=['SENT_283']),
#  TaggedDocument(words=['ASEAN', 'Leaders', 'Hold', 'Virtual', 'Summit', 'Amid', 'COVID-19', 'Pandemic'], tags=['SENT_284']),
#  TaggedDocument(words=['•', 'Coronavirus', 'deaths', 'per', 'million', 'country', '2020'], tags=['SENT_285']),
#  TaggedDocument(words=['India', 'extends', 'world', "'s", 'biggest', 'lockdown', 'ignites', 'protest', 'migrant', 'workers'], tags=['SENT_286']),
#  TaggedDocument(words=['Russia', 'sees', 'record', '2,558', 'new', 'daily', 'cases', 'coronavirus', 'Moscow', 'launches', 'digital', 'permits'], tags=['SENT_287']),
#  TaggedDocument(words=['OPEC', 'allies', 'agree', 'historic', 'oil', 'production', 'cut'], tags=['SENT_288']),
#  TaggedDocument(words=['Moscow', 'rolls', 'digital', 'tracking', 'enforce', 'lockdown', 'Critics', 'dub', "'cyber", 'Gulag'], tags=['SENT_289']),
#  TaggedDocument(words=['Taiwan', 'may', 'turn', 'traffic', 'advice', 'app', 'massive', 'tracking', 'system'], tags=['SENT_290']),
#  TaggedDocument(words=['Volunteers', 'Vietnam', 'set', 'rice', 'ATMs', 'provide', 'food', 'impacted', 'coronavirus'], tags=['SENT_291']),
#  TaggedDocument(words=['North', 'Korea', 'fires', 'barrage', 'missiles', 'ground', 'air'], tags=['SENT_292']),
#  TaggedDocument(words=['Coronavirus', '25,000', 'beds', 'needed', 'Covid-19', 'patients', 'months', 'come', 'secret', 'NHS', 'report', 'reveals'], tags=['SENT_293']),
#  TaggedDocument(words=['WHO', 'millions', 'children', 'risk', 'missing', 'measles', 'vaccines', 'amid', 'COVID-19', 'pandemic'], tags=['SENT_294']),
#  TaggedDocument(words=['Interstellar', 'object', '‘', 'Oumuamua', 'believed', '‘', 'active', 'asteroid', '’'], tags=['SENT_295']),
#  TaggedDocument(words=['Jordan', 'ban', 'mosque', 'prayers', 'fasting', 'month', 'Ramadan', 'minister'], tags=['SENT_296']),
#  TaggedDocument(words=['G7', 'agreed', 'need', 'aid', 'emerging', 'economies', 'battling', 'virus', 'Japan', "'s", 'Aso'], tags=['SENT_297']),
#  TaggedDocument(words=['Coronavirus', 'Army', 'veteran', 'Tom', 'Moore', '99', 'raises', '£4m', 'NHS'], tags=['SENT_298']),
#  TaggedDocument(words=['Coronavirus', 'Trump', 'says', 'US', 'halt', 'funding', 'WHO'], tags=['SENT_299']),
#  TaggedDocument(words=['Amid', 'pandemic', 'medical', 'groups', 'question', 'Turkey', '’', 'weekend', 'curfew', 'approach'], tags=['SENT_300']),
#  TaggedDocument(words=['IMF', 'cancels', 'debt', 'payments', 'six', 'months', 'allow', '25', 'poor', 'nations', 'boost', 'COVID-19', 'response'], tags=['SENT_301']),
#  TaggedDocument(words=['EU', 'countries', 'take', 'first', 'cautious', 'steps', 'coronavirus', 'lockdown'], tags=['SENT_302']),
#  TaggedDocument(words=['Communist', 'China', 'Uses', 'Internet', 'Trolls', 'To', 'Haze', 'Wuhan', 'Diary', 'Author'], tags=['SENT_303']),
#  TaggedDocument(words=['After', '50', 'Years', 'Effort', 'Researchers', 'Made', 'Silicon', 'Emit', 'Light'], tags=['SENT_304']),
#  TaggedDocument(words=['Police', 'foil', '€15m', 'plan', 'sell', 'Germany', 'fake', 'face', 'masks'], tags=['SENT_305']),
#  TaggedDocument(words=["'We", "'re", 'abandoned', 'fate', 'coronavirus', 'menaces', 'Brazil', "'s", 'favelas'], tags=['SENT_306']),
#  TaggedDocument(words=['Chief', 'Medical', 'Officer', 'Brendan', 'Murphy', 'takes', 'back', 'claim', 'hospital', 'staff', "'illegal", 'dinner', 'party', 'Tasmanian', 'coronavirus', 'outbreak'], tags=['SENT_307']),
#  TaggedDocument(words=['Italians', 'offered', 'EUR', '200', 'praising', 'Putin', "'s", 'help', 'camera', '–', 'media'], tags=['SENT_308']),
#  TaggedDocument(words=['Trump', 'halts', 'World', 'Health', 'Organization', 'funding', 'handling', 'coronavirus'], tags=['SENT_309']),
#  TaggedDocument(words=['A', 'Veterans', 'Hospital', 'Changed', 'Its', 'Coronavirus', 'Mask', 'Policy', 'After', 'Employees', 'Complained'], tags=['SENT_310']),
#  TaggedDocument(words=['India', "'s", 'Modi', 'extends', 'nationwide', 'coronavirus', 'lockdown', 'May', '3'], tags=['SENT_311']),
#  TaggedDocument(words=['Some', 'European', 'Nations', 'Ease', 'Pandemic', 'Rules', 'Move', 'Warily'], tags=['SENT_312']),
#  TaggedDocument(words=['Global', 'coronavirus', 'cases', 'approach', 'two', 'million', 'doubling', 'two', 'weeks'], tags=['SENT_313']),
#  TaggedDocument(words=['Rights', 'Groups', 'Hungary', '’', 'Coronavirus', 'Law', 'Creates', 'Indefinite', "'Dictatorship"], tags=['SENT_314']),
#  TaggedDocument(words=['Coronavirus', 'Air', 'travel', 'industry', 'predicted', 'lose', '£250bn', 'year'], tags=['SENT_315']),
#  TaggedDocument(words=['COVID-19', 'Cases', 'Near', 'Zero', 'Taiwan', 'But', 'Restrictions', 'Remain'], tags=['SENT_316']),
#  TaggedDocument(words=['Police', 'Spain', 'Hand', 'Out', 'Millions', 'Masks', 'Commuters'], tags=['SENT_317']),
#  TaggedDocument(words=['PM', 'Modi', 'extends', 'national', 'lockdown', 'till', 'May', '3', 'next', 'one', 'week', 'crucial', 'Covid', 'fight'], tags=['SENT_318']),
#  TaggedDocument(words=['Nicaraguan', 'president', 'missing', 'action', 'nearly', 'one', 'month', 'counting'], tags=['SENT_319']),
#  TaggedDocument(words=['Vancouver', 'protesters', 'call', 'coronavirus', 'fake', 'news', 'say', 'distancing', 'rule', 'defied', 'appalling', 'health', 'authorities'], tags=['SENT_320']),
#  TaggedDocument(words=['China', 'limited', 'Mekong', '’', 'flow', 'countries', 'suffered', 'drought'], tags=['SENT_321']),
#  TaggedDocument(words=["'Great", 'Lockdown', 'rival', 'Great', 'Depression', '3', 'hit', 'global', 'economy', 'says', 'IMF'], tags=['SENT_322']),
#  TaggedDocument(words=['UK', 'new', 'welfare', 'benefit', 'claims', 'soar', '1.4', 'million', 'minister', 'says'], tags=['SENT_323']),
#  TaggedDocument(words=['Lockdown', 'India', 'extended', 'till', 'May', '3', 'PM', 'Modi', 'announces'], tags=['SENT_324']),
#  TaggedDocument(words=['China', 'defends', 'WHO', 'Trump', '—', 'others', '—', 'say', 'deferring', 'Beijing'], tags=['SENT_325']),
#  TaggedDocument(words=['G-7', 'finance', 'ministers', 'open', 'suspending', 'debt', 'payments', 'needy', 'countries'], tags=['SENT_326']),
#  TaggedDocument(words=['Nearly', 'half', 'Canada', '’', 'COVID-19', 'deaths', 'linked', 'long-term', 'care', 'facilities', 'Tam'], tags=['SENT_327']),
#  TaggedDocument(words=['Imran', 'appeals', 'workers', 'abroad', 'virus', 'donations'], tags=['SENT_328']),
#  TaggedDocument(words=['French', 'Scientists', 'Dermatological', 'Ailments', 'Possibly', 'Sign', 'Coronavirus', 'Infection'], tags=['SENT_329']),
#  TaggedDocument(words=['Marriages', 'among', 'opposite-sex', 'couples', 'fall', 'record', 'low'], tags=['SENT_330']),
#  TaggedDocument(words=['``', 'It', "'s", 'early', 'ease', 'restrictions', "''"], tags=['SENT_331']),
#  TaggedDocument(words=['Five', 'B-52s', 'Six', 'KC-135s', 'Along', 'With', 'RQ-4', 'MQ-4C', 'MH-60S', 'Take', 'Part', 'Elephant', 'Walk', 'Andersen', 'AFB', 'Guam'], tags=['SENT_332']),
#  TaggedDocument(words=['New', 'study', 'suggests', 'COVID-19', 'hopped', 'dogs', 'humans', 'Here', "'s", 'skeptical'], tags=['SENT_333']),
#  TaggedDocument(words=['IMF', 'approves', 'debt', 'relief', '25', 'poor', 'countries'], tags=['SENT_334']),
#  TaggedDocument(words=['Despite', 'COVID', 'Amazon', 'deforestation', 'races', 'higher'], tags=['SENT_335']),
#  TaggedDocument(words=['338Canada', 'Canadians', 'overwhelmingly', 'satisfied', 'governments', 'COVID-19', 'responses'], tags=['SENT_336']),
#  TaggedDocument(words=["'Mixed", 'picture', 'Europe', 'COVID-19', 'vaccine', 'least', '12', 'months', 'WHO'], tags=['SENT_337']),
#  TaggedDocument(words=['China', 'Reports', '169', 'New', 'Coronavirus', 'Cases', '—', 'Highest', 'In', '5', 'Weeks'], tags=['SENT_338']),
#  TaggedDocument(words=['Virgin', 'Australia', 'goes', 'trading', 'halt', 'ponders', 'financial', 'options', 'stay', 'afloat'], tags=['SENT_339']),
#  TaggedDocument(words=['Scientists', 'Observed', 'Biggest', 'Supernova', 'Ever', 'Seen', 'Universe'], tags=['SENT_340']),
#  TaggedDocument(words=['Chinese', 'dams', 'held', 'back', 'Mekong', 'waters', 'drought', 'study', 'finds'], tags=['SENT_341']),
#  TaggedDocument(words=['Coronavirus', 'Russia', "'s", 'Putin', 'may', 'deploy', 'army', 'cases', 'surge'], tags=['SENT_342']),
#  TaggedDocument(words=['Hundreds', 'thousands', 'return', 'work', 'Spain', 'relaxes', 'coronavirus', 'lockdown'], tags=['SENT_343']),
#  TaggedDocument(words=['Young', 'British', 'men', 'emerging', 'new', 'group', 'online', 'paedophiles', 'says', 'police', 'chief'], tags=['SENT_344']),
#  TaggedDocument(words=['Most', 'COVID-19', 'Cases', 'Imported', 'Brazil', 'Came', 'Italy', 'Study', 'Finds'], tags=['SENT_345']),
#  TaggedDocument(words=['Australia', 'renewables', 'hit', '50', 'main', 'grid', '’', 'net', 'demand', 'Easter', 'Saturday'], tags=['SENT_346']),
#  TaggedDocument(words=['Coronavirus', 'Raspberry', 'Pi-powered', 'ventilator', 'tested', 'Colombia'], tags=['SENT_347']),
#  TaggedDocument(words=['Russian', 'Foreign', 'Minister', 'Calls', 'Unity', 'Fighting', 'COVID'], tags=['SENT_348']),
#  TaggedDocument(words=['Indonesian', 'Neighborhood', 'Uses', "'Ghosts", 'Scare', 'People', 'Back', 'Home'], tags=['SENT_349']),
#  TaggedDocument(words=['Putin', 'says', 'Russia', 'may', 'need', 'army', 'help', 'battle', 'coronavirus'], tags=['SENT_350']),
#  TaggedDocument(words=['Coronavirus', 'pushes', 'England', 'Wales', 'death', 'rate', 'record', 'high'], tags=['SENT_351']),
#  TaggedDocument(words=['Coronavirus', 'Trump', 'says', 'US', 'halt', 'funding', 'WHO'], tags=['SENT_352']),
# ...
#  TaggedDocument(words=['Survey', 'Finds', 'Working', 'From', 'Home', 'Has', 'So', 'Many', 'Benefits', '48', 'Workers', 'Would', 'Take', 'Pay', 'Cut', 'Continue'], tags=['SENT_755']),
#  TaggedDocument(words=['Coronavirus', '50', 'corpses', 'discovered', 'US', 'trucks', 'neighbours', 'noticed', 'smell', 'leaks'], tags=['SENT_756']),
#  TaggedDocument(words=['Coronavirus', 'WHO', "'not", 'invited', 'join', 'China', "'s", 'COVID-19', 'investigations'], tags=['SENT_757']),
#  TaggedDocument(words=['Japanese', 'city', 'cuts', '800,000', 'tulips', 'visitors', 'refuse', 'stay', 'away', 'cancelled', 'flower', 'festival'], tags=['SENT_758']),
#  TaggedDocument(words=['Israel', '’', 'Largest', 'Bank', 'Bank', 'Hapoalim', 'Admits', 'Conspiring', 'U.S.', 'Taxpayers', 'Hide', 'Assets', 'Income', 'Offshore', 'Accounts'], tags=['SENT_759']),
#  TaggedDocument(words=['Canada', "'s", 'early', 'COVID-19', 'cases', 'came', 'U.S.', 'China', 'provincial', 'data', 'shows'], tags=['SENT_760']),
#  TaggedDocument(words=['Special', 'Report', 'Trump', 'told', 'Saudi', 'Cut', 'oil', 'supply', 'lose', 'U.S.', 'military', 'support', 'sources'], tags=['SENT_761']),
#  TaggedDocument(words=['Greenhouse', 'Gas', 'Emissions', 'Predicted', 'To', 'Fall', 'Nearly', '8', '—', 'Largest', 'Decrease', 'Ever'], tags=['SENT_762']),
#  TaggedDocument(words=['In', 'Victory', 'Women', 'Sudan', 'Female', 'Genital', 'Mutilation', 'Is', 'Outlawed'], tags=['SENT_763']),
#  TaggedDocument(words=['Australia', 'back', 'Taiwan', "'s", 'return', 'WHO'], tags=['SENT_764']),
#  TaggedDocument(words=['New', 'Study', 'Reveals', 'That', '81', 'World', 'Population', 'Is', 'Calling', 'Upon', 'Billionaires', 'Contribute', 'More', 'Charity', '–', 'Especially', 'During', 'COVID-19', 'Pandemic', '–', 'Press', 'Releases', 'CSRwire.com'], tags=['SENT_765']),
#  TaggedDocument(words=['Taiwan', 'rejoining', 'World', 'Health', 'Organization', 'still', 'backed', 'Australia', 'diplomatically', 'risky', 'move'], tags=['SENT_766']),
#  TaggedDocument(words=['China', 'threatens', 'halt', 'medical', 'supplies', 'afte', '...'], tags=['SENT_767']),
#  TaggedDocument(words=['Xiaomi', 'Devices', 'Found', 'Tracking', 'And', 'Recording', 'Browsing', 'Data', 'Of', 'Millions'], tags=['SENT_768']),
#  TaggedDocument(words=['China', 'Warns', 'Australia', 'It', 'Could', 'Face', 'Boycotts', 'Over', 'Call', 'Independent', 'Inquiry', 'Into', 'Coronavirus'], tags=['SENT_769']),
#  TaggedDocument(words=['LED', 'lights', 'halve', 'unwanted', 'fish', 'nets', 'research', 'finds'], tags=['SENT_770']),
#  TaggedDocument(words=['EU', 'chief', 'backs', 'investigation', 'coronavirus', 'origin', 'says', 'China', 'involved'], tags=['SENT_771']),
#  TaggedDocument(words=['Japanese', 'island', 'suffering', 'second', 'wave', 'coronavirus', 'lifting', 'lockdown', 'early'], tags=['SENT_772']),
#  TaggedDocument(words=['Chinese', 'journalist', 'jailed', 'criticising', 'Communist', 'Party'], tags=['SENT_773']),
#  TaggedDocument(words=['Coronavirus', 'David', 'Icke', 'kicked', 'Facebook'], tags=['SENT_774']),
#  TaggedDocument(words=['Trudeau', 'announces', 'ban', '1,500', 'types', "'assault-style", 'firearms', '—', 'effective', 'immediately'], tags=['SENT_775']),
#  TaggedDocument(words=['Four-in-five', 'Canadians', 'support', 'complete', 'ban', 'civilian', 'possession', 'assault', 'style', 'weapons'], tags=['SENT_776']),
#  TaggedDocument(words=['Canada', 'bans', 'assault', 'weapons', 'following', 'worst-ever', 'mass', 'shooting'], tags=['SENT_777']),
#  TaggedDocument(words=['Lawmakers', 'demand', 'Jeff', 'Bezos', 'testify', 'Amazon', "'s", 'alleged', 'misuse', 'data'], tags=['SENT_778']),
#  TaggedDocument(words=['Imported', 'rich', 'coronavirus', 'devastating', 'Brazil', "'s", 'poor'], tags=['SENT_779']),
#  TaggedDocument(words=['President', "'s", "'So", '5,000', 'die', 'sparks', 'fury', 'Brazil'], tags=['SENT_780']),
#  TaggedDocument(words=['Japanese', 'aquarium', 'urges', 'public', 'video-chat', 'eels', 'forgetting', 'humans', 'exist'], tags=['SENT_781']),
#  TaggedDocument(words=['Thailand', "'s", 'king', 'living', 'luxury', 'quarantine', 'country', 'suffers'], tags=['SENT_782']),
#  TaggedDocument(words=['Coronavirus', 'NSW', 'Dossier', 'lays', 'case', 'China', 'bat', 'virus', 'program'], tags=['SENT_783']),
#  TaggedDocument(words=['Earth', "'s", 'Insect', 'Population', 'Shrunk', '‘', 'Jaw-Dropping', '’', '27', 'Over', 'Past', '30', 'Years'], tags=['SENT_784']),
#  TaggedDocument(words=['Putin', 'critic', 'vows', '‘', 'tell', 'truth', '’', 'COVID-19', 'crisis', 'Russia', 'despite', 'threats', 'life'], tags=['SENT_785']),
#  TaggedDocument(words=['Coronavirus', 'Amazon', 'deforestation', 'could', 'trigger', 'new', 'pandemics', 'experts', 'warn', 'amid', 'fears', 'Brazilian', 'land', 'ownership', 'law'], tags=['SENT_786']),
#  TaggedDocument(words=['Fire', 'attacks', 'Scottish', 'phone', 'masts', 'soar', 'bogus', '5G', 'coronavirus', 'conspiracy', 'theory', 'spreads'], tags=['SENT_787']),
#  TaggedDocument(words=['Pope', "'s", "'Robin", 'Hood', 'Wired', 'Money', 'For', 'Food', 'To', 'Struggling', 'Transgender', 'Sex', 'Workers'], tags=['SENT_788']),
#  TaggedDocument(words=['Russia', 'sees', 'record', 'spike', 'coronavirus', 'cases', 'nearly', '10,000', 'one', 'day'], tags=['SENT_789']),
#  TaggedDocument(words=['US', 'tweets', 'support', 'Taiwan', 'sparking', 'opposition', 'China'], tags=['SENT_790']),
#  TaggedDocument(words=['Coronavirus', 'World', 'must', 'prepare', 'second', 'third', 'wave', 'Covid-19', 'WHO', 'warns'], tags=['SENT_791']),
#  TaggedDocument(words=['Brazil', 'Has', 'Highest', 'Rate', 'Coronavirus', 'Contagion', 'World', 'Says', 'Study'], tags=['SENT_792']),
#  TaggedDocument(words=['Coronavirus', 'Scientists', 'conclude', 'people', 'infected', 'twice'], tags=['SENT_793']),
#  TaggedDocument(words=['Climate', 'crisis', 'Coronavirus', 'causing', 'collapse', 'demand', 'fossil', 'fuels', 'renewables', 'make', 'major', 'gains', 'according', 'major', 'global', 'report'], tags=['SENT_794']),
#  TaggedDocument(words=['Australia', 'could', 'get', '90', 'electricity', 'renewables', '2040', 'price', 'increase'], tags=['SENT_795']),
#  TaggedDocument(words=['China', 'deliberately', 'destroyed', 'evidence', 'start', 'coronavirus', 'report', 'says'], tags=['SENT_796']),
#  TaggedDocument(words=['Coronavirus', 'Boris', 'Johnson', 'says', "'arrangements", 'made', 'case', 'died'], tags=['SENT_797']),
#  TaggedDocument(words=['Brazil', "'s", 'President', 'Is', 'Out', 'With', 'Another', 'Super-Bad', 'Coronavirus', 'Take', 'Soccer', 'Players', 'Ca', "n't", 'Die', 'From', 'It'], tags=['SENT_798']),
#  TaggedDocument(words=['Commercial', 'whaling', 'may', 'Iceland'], tags=['SENT_799']),
#  TaggedDocument(words=['Satellites', 'reveal', 'clearest', 'picture', 'ice-melting', 'Antarctica'], tags=['SENT_800']),
#  TaggedDocument(words=['Coronavirus', 'city', 'branded', "'new", 'Wuhan', 'corpses', 'pile', 'streets'], tags=['SENT_801']),
#  TaggedDocument(words=['Russia', 'BILLED', 'US', '600,000', 'medical', 'supplies', 'sent', "'aid", 'flight', 'Putin', 'offered', 'Trump'], tags=['SENT_802']),
#  TaggedDocument(words=['Minor', 'rape', 'victim', '’', 'right', 'abort', 'outweighs', 'foetus', '’', 'right', 'born', 'Rajasthan', 'High', 'Court'], tags=['SENT_803']),
#  TaggedDocument(words=['Third', 'Russian', 'doctor', 'plunges', 'coronavirus', 'hospital', 'window'], tags=['SENT_804']),
#  TaggedDocument(words=['‘', 'We', 'eve', 'genocide', '’', 'Brazil', 'urged', 'save', 'Amazon', 'tribes', 'Covid-19'], tags=['SENT_805']),
#  TaggedDocument(words=['Pope', 'says', 'coronavirus', 'vaccine', 'must', 'shared', 'worldwide'], tags=['SENT_806']),
#  TaggedDocument(words=['Coronavirus', 'Hong', 'Kong', 'records', 'new', 'cases', 'Sunday', 'marking', '14', 'straight', 'days', 'without', 'local', 'infection'], tags=['SENT_807']),
#  TaggedDocument(words=['Coronavirus', 'Almost', 'half', 'doctors', 'buy', 'PPE', 'rely', 'donations', 'survey', 'shows'], tags=['SENT_808']),
#  TaggedDocument(words=['Brazil', 'president', 'still', 'telling', 'people', "'ignore", 'lockdown', 'despite', '6,000', 'coronavirus', 'deaths'], tags=['SENT_809']),
#  TaggedDocument(words=['New', 'report', 'says', 'coronavirus', 'pandemic', 'could', 'last', 'two', 'years', '–', 'may', 'subside', '70', 'population', 'immunity'], tags=['SENT_810']),
#  TaggedDocument(words=['Rome', '’', 'seagulls', 'hunt', 'rats', 'pigeons', 'lockdown', 'starves', 'scraps'], tags=['SENT_811']),
#  TaggedDocument(words=['Payday', 'Lenders', 'Are', 'Charging', 'Up', '780', 'Interest', 'Amid', 'Coronavirus', 'Panic'], tags=['SENT_812']),
#  TaggedDocument(words=['Coronavirus', 'Covid', '19', 'Zero', 'new', 'cases', 'today', 'Ashley', 'Bloomfield'], tags=['SENT_813']),
#  TaggedDocument(words=['Missourians', 'tipped', 'county', 'lockdown', 'rule-breakers', 'fear', 'retaliation', 'detail', 'release'], tags=['SENT_814']),
#  TaggedDocument(words=['President', 'Queries', 'Tanzania', 'Coronavirus', 'Kits', 'After', 'Goat', 'Test'], tags=['SENT_815']),
#  TaggedDocument(words=['Canada', 'pledges', '170M', 'develop', 'online', 'mental', 'health', 'services', 'amid', 'coronavirus', 'outbreak'], tags=['SENT_816']),
#  TaggedDocument(words=['72', 'Japan', 'see', 'closure', 'unregulated', 'meat', 'markets', 'key', 'preventing', 'pandemics', 'survey', 'finds'], tags=['SENT_817']),
#  TaggedDocument(words=['Exclusive', 'Internal', 'Chinese', 'report', 'warns', 'Beijing', 'faces', 'Tiananmen-like', 'global', 'backlash', 'virus'], tags=['SENT_818']),
#  TaggedDocument(words=['UK', 'scientists', 'create', 'coronavirus', 'antibody', 'test', "'99.8", 'accuracy', 'results', '35', 'minutes'], tags=['SENT_819']),
#  TaggedDocument(words=['India', 'offers', 'land', 'twice', 'Luxembourg', '’', 'size', 'firms', 'leaving', 'China'], tags=['SENT_820']),
#  TaggedDocument(words=['Trump', 'administration', 'pushing', 'rip', 'global', 'supply', 'chains', 'China', 'officials'], tags=['SENT_821']),
#  TaggedDocument(words=['Italy', 'begins', 'emerge', 'world', "'s", 'longest', 'lockdown'], tags=['SENT_822']),
#  TaggedDocument(words=['Putin', '’', 'popularity', 'collapses', 'coronavirus-ravaged', 'Russia', 'country', 'biggest', 'daily', 'rise', 'Europe'], tags=['SENT_823']),
#  TaggedDocument(words=['‘', 'Time', 'come', '’', 'universal', 'basic', 'income', 'says', 'Sturgeon'], tags=['SENT_824']),
#  TaggedDocument(words=['World', 'leaders', 'pledge', 'fight', 'coronavirus', 'U.S.', 'skips', 'meeting'], tags=['SENT_825']),
#  TaggedDocument(words=['WHO', 'says', 'US', "n't", 'shared', 'evidence', 'linking', 'coronavirus', 'Chinese', 'lab'], tags=['SENT_826']),
#  TaggedDocument(words=['Members', 'Germany', '’', 'ruling', 'coalition', 'tell', 'Trump', 'take', 'U.S.', 'nukes', 'home'], tags=['SENT_827']),
#  TaggedDocument(words=['Grateful', 'Irish', 'honour', 'Famine', 'debt', 'Choctaw', 'tribe'], tags=['SENT_828']),
#  TaggedDocument(words=['Covid', '19', 'coronavirus', 'Zero', 'new', 'cases', 'second', 'day', 'row'], tags=['SENT_829']),
#  TaggedDocument(words=['Union', 'questions', 'worker', 'safety', 'Cargill', 'reopens', 'plant', 'centre', 'COVID-19', 'outbreak'], tags=['SENT_830']),
#  TaggedDocument(words=['HK', 'protesters', 'say', 'tortured', 'prison'], tags=['SENT_831']),
#  TaggedDocument(words=['Reuters', 'wins', 'Pulitzer', 'Prize', 'breaking', 'news', 'photography', 'Hong', 'Kong', 'protests'], tags=['SENT_832']),
#  TaggedDocument(words=['Taiwan', 'rebuffs', 'WHO', 'says', 'China', 'right', 'represent'], tags=['SENT_833']),
#  TaggedDocument(words=["'The", 'favour', 'returned', 'Native', 'American', 'Covid-19', 'relief', 'fund', 'thanks', 'Irish', 'people', 'support'], tags=['SENT_834']),
#  TaggedDocument(words=['‘', 'Near-unlivable', '’', 'heat', 'one-third', 'humans', 'within', '50', 'years', 'greenhouse', 'gas', 'emissions', 'cut'], tags=['SENT_835']),
#  TaggedDocument(words=['Boris', 'Johnson', 'continued', 'shake', 'hands', 'scientific', 'advisers', 'warned', 'could', 'spread', 'coronavirus'], tags=['SENT_836']),
#  TaggedDocument(words=["'This", 'God', 'wanted', 'Top', 'Egyptian', 'actor', 'reveals', 'son', 'tran'], tags=['SENT_837']),
#  TaggedDocument(words=['‘', 'Please', 'stop', 'nonsense', '’', 'Japanese', 'decry', 'boomer-era', 'technology', 'hospitals', 'file', 'Covid-19', 'cases', 'fax'], tags=['SENT_838']),
#  TaggedDocument(words=['13', 'rangers', 'caring', 'gorillas', 'perfectly', 'posed', 'selfie', 'killed'], tags=['SENT_839']),
#  TaggedDocument(words=['Kim', 'Jong', 'Un', '’', 'First', 'Public', 'Appearance', 'In', 'Weeks', 'Sparks', 'Theories', 'That', 'North', 'Korea', 'Actually', 'Used', 'A', 'Body', 'Double'], tags=['SENT_840']),
#  TaggedDocument(words=['Prague', 'revamp', 'reveals', 'Jewish', 'gravestones', 'used', 'pave', 'streets'], tags=['SENT_841']),
#  TaggedDocument(words=['NZ', 'foreign', 'minister', 'backs', 'Taiwan', "'s", 'entry', '...'], tags=['SENT_842']),
#  TaggedDocument(words=['Brazil', 'sacks', 'officials', 'curbed', 'deforestation', 'Amazon', 'indigenous', 'lands'], tags=['SENT_843']),
#  TaggedDocument(words=['Coronavirus', 'quickly', 'spread', 'around', 'world', 'starting', 'late', 'last', 'year', 'new', 'genetic', 'analysis', 'shows'], tags=['SENT_844']),
#  TaggedDocument(words=['Hungary', 'longer', 'democracy', 'report'], tags=['SENT_845']),
#  TaggedDocument(words=['Taiwan', 'says', 'WHO', "'free", '...'], tags=['SENT_846']),
#  TaggedDocument(words=['Putin', '’', 'Approval', 'Rating', 'Drops', 'Historic', 'Low', 'Poll'], tags=['SENT_847']),
#  TaggedDocument(words=['U.S.', 'allies', 'report', 'China', 'deliberately', 'destroyed', 'laboratory', 'evidence', 'made', 'whistleblowers', 'disappear'], tags=['SENT_848']),
#  TaggedDocument(words=['China', 'says', 'Hong', 'Kong', 'never', 'calm', 'unless', 'violent', 'protesters', 'removed'], tags=['SENT_849']),
#  TaggedDocument(words=['China', 'calls', 'Hong', 'Kong', 'protesters', '‘', 'virus', '’', 'says', 'city', '’', 'calm', '’', 'removed'], tags=['SENT_850']),
#  TaggedDocument(words=['Viktor', 'Orban', '’', 'Hungary', 'longer', 'democracy', 'Freedom', 'House', 'says'], tags=['SENT_851']),
#  TaggedDocument(words=['US', 'demands', 'WHO', 'invite', 'Taiwan', 'meeting'], tags=['SENT_852']),
#  TaggedDocument(words=['Biggest', 'shark', 'fin', 'seizure', 'Hong', 'Kong', 'history', 'recovers', '26', 'tonnes', 'mostly', 'endangered', 'species', 'shipments', 'Ecuador'], tags=['SENT_853']),
#  TaggedDocument(words=['COVID-19', 'Sikh', 'doctors', 'Canada', 'take', '‘', 'extremely', 'difficult', 'decision', '’', 'shave', 'beards'], tags=['SENT_854']),
#  TaggedDocument(words=['No', 'cookie', 'consent', 'walls', '—', 'scrolling', '’', 'consent', 'says', 'EU', 'data', 'protection', 'body', '–', 'TechCrunch'], tags=['SENT_855']),
#  TaggedDocument(words=['Popular', 'Philippines', 'radio', 'show', 'host', '‘', 'Rex', 'Cornello', '’', 'shot', 'dead', 'ambush'], tags=['SENT_856']),
#  TaggedDocument(words=['Nobel', 'Prize', 'winner', "'greatly", 'saddened', 'name', 'used', 'spread', 'COVID-19', 'misinformation'], tags=['SENT_857']),
#  TaggedDocument(words=['77', 'cell', 'phone', 'towers', 'set', 'fire', 'far', 'due', 'weird', 'coronavirus', '5G', 'conspiracy', 'theory'], tags=['SENT_858']),
#  TaggedDocument(words=['Americans', 'Have', 'More', 'Trust', 'In', 'Canadians', 'Than', 'Themselves', 'Poll', 'Suggests'], tags=['SENT_859']),
#  TaggedDocument(words=['China', 'Vows', 'To', 'Brutally', 'Crush', 'Hong-Kong', 'Protesters'], tags=['SENT_860']),
#  TaggedDocument(words=['In', 'aftermath', 'outbreak', 'New', 'Zealand', 'jumps', 'board', 'Taiwan', 'WHO', 'push'], tags=['SENT_861']),
#  TaggedDocument(words=['India', 'Looks', 'Lure', 'More', 'Than', '1,000', 'U.S.', 'Companies', 'Out', 'China'], tags=['SENT_862']),
#  TaggedDocument(words=['US', 'delay', 'Hong', 'Kong', 'report', 'see', 'China', "'further", 'undermines', 'autonomy'], tags=['SENT_863']),
#  TaggedDocument(words=['Satellite', 'images', 'reveal', 'North', 'Korea', 'building', 'giant', 'facility', 'could', 'hold', 'nuclear', 'missiles', 'capable', 'hitting', 'United', 'States'], tags=['SENT_864'])]

# %% [markdown]
# ### Pickle the tag_lookup dictionary so I can load it later in my data app

# %%
with open('tag_lookup.pickle', 'wb') as f:
    pickle.dump(tag_lookup, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Build and train a Doc2Vec model

# %%
model = Doc2Vec(alpha=0.025, min_alpha=0.025)
model.build_vocab(sentences)
model.train(sentences, total_examples=len(sentences), epochs=100)

# %% [markdown]
# ### The next step is to lookup a headline, find similar headlines, and compare the sentiment of that headline to other similar headlines.

# %%
# function to lookup a headline and find similar headlines
def find_similar(headline, topn):
    new_clean_headline = clean_headline(headline)
    similar = model.docvecs.most_similar(positive=[model.infer_vector(new_clean_headline)],topn=topn)

    return similar

# %% [markdown]
# ### Test the model on a headline not included in the training set

# %%
new_headline = 'this is a test headline, this is not real'
similar = find_similar(new_headline, 5)

print(f'{new_headline}')
blob = TextBlob(new_headline)
print(blob.sentiment)
print()

# show similar headlines
for i, s in enumerate(similar):
    print(f'{i}: {tag_lookup[s[0]]} -- {TextBlob(tag_lookup[s[0]]).sentiment}')
# Out:
# this is a test headline, this is not real
# Sentiment(polarity=-0.1, subjectivity=0.30000000000000004)
#
# 0: Two Brazilian governors test positive for coronavirus -- Sentiment(polarity=0.22727272727272727, subjectivity=0.5454545454545454)
# 1: UK scientists create coronavirus antibody test with '99.8% accuracy and results in 35 minutes' -- Sentiment(polarity=0.0, subjectivity=0.0)
# 2: Two Brazilian governors test positive for coronavirus -- Sentiment(polarity=0.22727272727272727, subjectivity=0.5454545454545454)
# 3: Rio de Janeiro governor tests positive for coronavirus -- Sentiment(polarity=0.22727272727272727, subjectivity=0.5454545454545454)
# 4: South Korea sending COVID-19 test kits to U.S. -- Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# ### Lookup an existing headline to see other similar headlines
# Since the headline I'm looking up was part of training, the most similar headline is always the same one I looked up. So to get the top 5 most similar headlines, I just get the top 6 and ignore the first.

# %%
new_headline = df['headline'][0]
similar = find_similar(new_headline, 6)
similar.pop(0)

print(f'{new_headline}')
blob = TextBlob(new_headline)
print(blob.sentiment)
print()

# show similar headlines
for i, s in enumerate(similar):
    print(f'{i}: {tag_lookup[s[0]]} -- {TextBlob(tag_lookup[s[0]]).sentiment}')
# Out:
# Top U.S. general resists Trump administration?s efforts to provoke war with Iran ? Mondoweiss
# Sentiment(polarity=0.275, subjectivity=0.5)
#
# 0: Iran: $1.6 Billion Released from Luxembourg to Go to Coronavirus -- Sentiment(polarity=0.0, subjectivity=0.0)
# 1: WHO hopes U.S. funding will continue -- Sentiment(polarity=0.0, subjectivity=0.0)
# 2: Luxembourg blocks US bid for $1.6 billion 9/11 compensation from Iran -- Sentiment(polarity=0.0, subjectivity=0.0)
# 3: Iran coronavirus fatalities drop to double figures for first time in month -- Sentiment(polarity=0.125, subjectivity=0.16666666666666666)
# 4: Armed men seize, release tanker off Iran by Strait of Hormuz -- Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# ### Presenting the results
# I figured the best way to present these results would be a data app. This way a user can select whatever headline they want and find similar ones. To do this, I will save the Doc2Vec model to a file and load it from the app.

# %%
model.save('headline_model')

# %% [markdown]
# Test loading the model to make sure it works

# %%
loaded_model = Doc2Vec.load('headline_model')

new_headline = df['headline'][1]
new_clean_headline = clean_headline(new_headline)
similar = loaded_model.docvecs.most_similar(positive=[model.infer_vector(new_clean_headline)],topn=6)
similar.pop(0)

print(f'{new_headline}')
blob = TextBlob(new_headline)
print(blob.sentiment)
print()

# show similar headlines
for i, s in enumerate(similar):
    print(f'{i}: {tag_lookup[s[0]]} -- {TextBlob(tag_lookup[s[0]]).sentiment}')
# Out:
# Atalanta vs Valencia linked to accelerating coronavirus spread
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# 0: Boris Johnson continued to shake hands after his own scientific advisers warned it could spread the coronavirus -- Sentiment(polarity=0.6, subjectivity=1.0)
# 1: Air-conditioning spread the coronavirus to 9 people sitting near an infected person in a restaurant, researchers say. It has huge implications for the service industry. -- Sentiment(polarity=0.25000000000000006, subjectivity=0.65)
# 2: Coronavirus: Labour official spread conspiracy theory that Boris Johnson did not have Covid-19 -- Sentiment(polarity=0.0, subjectivity=0.0)
# 3: China’s initial coronavirus outbreak in Wuhan spread twice as fast as we thought, new study suggests -- Sentiment(polarity=0.11212121212121212, subjectivity=0.3515151515151515)
# 4: NHS coronavirus app: memo discussed giving ministers power to 'de-anonymise' users -- Sentiment(polarity=0.0, subjectivity=0.0)
