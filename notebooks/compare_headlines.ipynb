# %% [markdown]
# # Find similar news headlines and compare sentiment
# Now that I have done sentiment analysis with headlines and worked with word vectors for article content, I came up with another question: Given a headline, can I look up other similar headlines and compare the sentiment?
# \
# \
# To do this, I use Doc2Vec to vectorize headlines and find other similar headlines. I can then perform sentiment analysis on these headlines using TextBlob.

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
import string
from sklearn.manifold import TSNE
from textblob import TextBlob
import pickle
import json

# %%
with open('../secrets.json') as file:
    secrets = json.load(file)
    connection_string = secrets['connection_string']
db = create_engine(connection_string)
df = pd.read_sql('select * from news_article', con=db)

# %%
df['headline'][0]
# Out:
# "Muons: 'Strong' evidence found for a new force of nature"

# %% [markdown]
# ### Function to tokenize headline, remove stop words and remove punctuation

# %%
def clean_headline(headline):
    stop_words = set(stopwords.words('english'))
    return [word for word in nltk.word_tokenize(headline) if word not in stop_words and word not in string.punctuation]

# %% [markdown]
# ### Prepare the data for Doc2Vec

# %%
# LabeledSentence(words=line.split(), labels=['SENT_%s' % uid])
stop_words = set(stopwords.words('english')) 

sentences = []
tag_lookup = {}

# tokenize headlines,remove stop words and punctuation
# Create a dictionary with the tags as keys so I can look up the actual headlines later.
# Also create a list of TaggedDocuments which will be used for training the model.
for i in range(len(df)):
    headline = clean_headline(df['headline'][i])
    tag = f'SENT_{i}'
    sentences.append(TaggedDocument(words=headline, tags=[tag]))
    tag_lookup.update({tag: df['headline'][i]})

sentences
# Out:
# [TaggedDocument(words=['Muons', "'Strong", 'evidence', 'found', 'new', 'force', 'nature'], tags=['SENT_0']),
#  TaggedDocument(words=['A', 'third', 'COVID', 'survivors', 'suffer', 'neurological', 'mental', 'disorders', 'study'], tags=['SENT_1']),
#  TaggedDocument(words=['U.S.', 'disturbed', 'imprisoned', 'Kremlin', 'critic', 'Navalny', "'s", 'deteriorating', 'health'], tags=['SENT_2']),
#  TaggedDocument(words=['Jailed', 'Kremlin', 'critic', 'Navalny', 'loses', 'sensation', 'hands', 'Lawyers'], tags=['SENT_3']),
#  TaggedDocument(words=['Taiwan', 'says', 'may', 'shoot', 'Chinese', 'drones', 'South', 'China', 'Sea'], tags=['SENT_4']),
#  TaggedDocument(words=['Wuhan', 'cemeteries', 'see', '320,000', 'early', 'mourners', 'Tomb', 'Sweeping', 'Festival', 'Chinese', 'media'], tags=['SENT_5']),
#  TaggedDocument(words=['Navalny', 'lawyer', 'says', 'opposition', 'leader', 'diagnosed', 'spinal', 'hernias'], tags=['SENT_6']),
#  TaggedDocument(words=['Rolls-Royce', 'hits', 'new', 'sales', 'record', 'first', 'quarter', 'wealthy', 'demand', 'luxury', 'cars'], tags=['SENT_7']),
#  TaggedDocument(words=['Israel', 'refuses', 'work', 'ICC', 'war', 'crimes', 'probe', 'says', "'no", 'authority'], tags=['SENT_8']),
#  TaggedDocument(words=['US', 'considering', 'sending', 'warships', 'Black', 'Sea', 'amid', 'Russia-Ukraine', 'tensions'], tags=['SENT_9']),
#  TaggedDocument(words=['Armed', 'clashes', 'break', 'Myanmar', 'troops', 'anti-junta', 'protesters', 'US', 'expands', 'sanctions'], tags=['SENT_10']),
#  TaggedDocument(words=['Japan', 'Says', 'Sorry', 'But', 'It', 'Has', 'Dump', 'This', 'Radioactive', 'Water', 'Into', 'Ocean'], tags=['SENT_11']),
#  TaggedDocument(words=['Boris', 'Johnson', 'calls', 'calm', 'fiery', 'fourth', 'night', 'violence', 'Northern', 'Ireland'], tags=['SENT_12']),
#  TaggedDocument(words=['COVID-19', "n't", 'slowed', 'global', 'warming', 'Earth', "'s", 'carbon', 'dioxide', 'levels', 'highest', '3', 'million', 'years', 'NOAA', 'says'], tags=['SENT_13']),
#  TaggedDocument(words=['Russia-Ukraine', 'border', 'crisis', 'Merkel', 'demanded', 'Putin', 'reduce', 'Russian', 'troops', 'around', 'Ukraine'], tags=['SENT_14']),
#  TaggedDocument(words=['China', 'Backs', 'Away', 'Philippines', 'U.S', 'Send', 'Impressive', 'Fleet', 'West', 'Philippine', 'Sea'], tags=['SENT_15']),
#  TaggedDocument(words=['Hong', 'Kongers', 'say', "'re", 'targeted', 'Chinese', 'agents', 'Canadian', 'soil'], tags=['SENT_16']),
#  TaggedDocument(words=['Erosion', 'democracy', 'real', 'problem', 'many', 'parts', 'world', 'CIA', 'chief'], tags=['SENT_17']),
#  TaggedDocument(words=['3', 'resign', 'Auschwitz', 'museum', 'board', 'appointment', 'right-wing', 'politician'], tags=['SENT_18']),
#  TaggedDocument(words=['New', 'Zealand', 'wants', 'ban', 'cigarette', 'sales', 'anyone', 'born', '2004', 'part', 'plan', 'make', 'nation', '‘', 'smoke', 'free', '’', '2025'], tags=['SENT_19']),
#  TaggedDocument(words=['The', 'Decades-Long', 'Persecution', 'Human', 'Rights', 'Lawyer', 'Oil', 'Giant', '–', 'Byline', 'Times'], tags=['SENT_20']),
#  TaggedDocument(words=['Russia', 'Ukraine', "'on", 'doorstep', 'war', 'half', 'million', 'troops', 'move'], tags=['SENT_21']),
#  TaggedDocument(words=['Batches', '50', '100', 'Uighur', 'workers', 'advertised', 'Chinese', 'internet'], tags=['SENT_22']),
#  TaggedDocument(words=['‘', 'The', 'rich', 'think', 'buy', 'want', 'even', 'lives', '’', 'Anger', 'Brazil', '’', 'vaccination', 'plan', 'Covid', 'rages'], tags=['SENT_23']),
#  TaggedDocument(words=['Paris', 'lockdown', 'deadly', 'hospital', 'shooting', 'gunman', 'flees', 'city', 'motorbike'], tags=['SENT_24']),
#  TaggedDocument(words=['Ottawa', 'cancels', '29', 'military', 'export', 'permits', 'Turkey', 'finding', 'Canadian-made', 'gear', 'diverted', 'Nagorno-Karabakh', 'conflict'], tags=['SENT_25']),
#  TaggedDocument(words=['France', 'ban', 'domestic', 'flights', 'train', 'available'], tags=['SENT_26']),
#  TaggedDocument(words=['UN', 'chief', 'urges', 'wealth', 'tax', 'profited', 'COVID'], tags=['SENT_27']),
#  TaggedDocument(words=['Citing', 'grave', 'threat', 'Scientific', 'American', 'replaces', "'climate", 'change', "'climate", 'emergency'], tags=['SENT_28']),
#  TaggedDocument(words=['Ukraine', "'s", 'President', 'heads', 'trenches', 'Russia', 'masses', 'troops'], tags=['SENT_29']),
#  TaggedDocument(words=['Ukraine', 'Tells', 'Russia', 'Pull', 'Back', 'Troops', 'U.S', 'Warns', 'Costs'], tags=['SENT_30']),
#  TaggedDocument(words=['Taiwan', 'reports', 'largest', 'incursion', 'yet', 'Chinese', 'air', 'force'], tags=['SENT_31']),
#  TaggedDocument(words=['Indonesian', 'submarine', 'declared', 'sunk', 'hope', 'survivors'], tags=['SENT_32']),
#  TaggedDocument(words=['India', 'orders', 'Twitter', 'take', 'tweets', 'critical', 'coronavirus', 'handling', '–', 'TechCrunch'], tags=['SENT_33']),
#  TaggedDocument(words=['Interpreters', 'helped', 'Australian', 'forces', 'Afghanistan', 'plead', 'visas', 'escape', '‘', 'extreme', 'threats', '’'], tags=['SENT_34']),
#  TaggedDocument(words=['Nepal', 'becomes', 'first', 'country', 'Asia', 'Pacific', 'vaccinate', 'refugees', 'COVID-19'], tags=['SENT_35']),
#  TaggedDocument(words=['Bad', 'software', 'sent', 'postal', 'workers', 'jail', 'one', 'wanted', 'admit', 'could', 'wrong'], tags=['SENT_36']),
#  TaggedDocument(words=['Biden', 'told', 'Erdogan', 'plans', 'call', '1915', 'massacres', 'Armenians', 'genocide', '-sources'], tags=['SENT_37']),
#  TaggedDocument(words=['Families', 'allowed', 'bury', 'dead', 'backyards', 'India', "'s", 'Covid-19', 'surge', 'overwhelms', 'crematoriums'], tags=['SENT_38']),
#  TaggedDocument(words=['German', 'actors', 'criticized', 'coronavirus', 'protest', 'videos'], tags=['SENT_39']),
#  TaggedDocument(words=['Brazil', 'cuts', 'environment', 'spending', 'one', 'day', 'U.S.', 'climate', 'summit', 'pledge'], tags=['SENT_40']),
#  TaggedDocument(words=['Twitter', 'Is', 'Blocking', 'Tweets', 'That', 'Criticize', 'How', 'The', 'Indian', 'Government', 'Has', 'Handled', 'The', 'Pandemic'], tags=['SENT_41']),
#  TaggedDocument(words=['Mexico', "'s", 'drought', 'reaches', 'critical', 'levels', 'lakes', 'dry'], tags=['SENT_42']),
#  TaggedDocument(words=['India', 'asks', 'Twitter', 'take', 'tweets', 'critical', 'COVID-19', 'handling'], tags=['SENT_43']),
#  TaggedDocument(words=['Extremist', 'Arab', 'reporter', 'neighbor', 'I', 'want', 'expel', 'burn', 'village'], tags=['SENT_44']),
#  TaggedDocument(words=["'Humanity", 'first', 'Pakistan', 'offers', 'support', 'India', 'Covid', 'fight'], tags=['SENT_45']),
#  TaggedDocument(words=['Norway', 'Dozens', 'hospitalized', 'underground', 'bunker', 'party'], tags=['SENT_46']),
#  TaggedDocument(words=['Borders', 'Closing', 'Hungary', 'Revive', 'Restrictive', 'Measures', 'Sept', '1'], tags=['SENT_47']),
#  TaggedDocument(words=['The', 'Only', 'Mongolian-Language', 'Social', 'Media', 'Site', 'Was', 'Shut', 'Down', 'China'], tags=['SENT_48']),
#  TaggedDocument(words=['Boris', 'Johnson', "'ca", "n't", 'trusted', 'foreign', 'aid', 'millions', 'sent', 'China', 'revealed'], tags=['SENT_49']),
#  TaggedDocument(words=['Denied', 'Fair', 'Trial', 'Disregarded', '238', 'Days', 'Kurdish', 'Activist', 'Dies', 'Hunger', 'Strike', 'Turkish', 'Jail'], tags=['SENT_50']),
#  TaggedDocument(words=['Coronavirus', 'India', 'crosses', '80,000', 'cases', 'day', 'first', 'country'], tags=['SENT_51']),
#  TaggedDocument(words=['With', 'Canada', 'Mexico', 'borders', 'closed', 'Americans', 'trapped', 'healthcare', 'system'], tags=['SENT_52']),
#  TaggedDocument(words=['Two', 'teen', 'boys', '‘', 'tortured', 'raped', 'buried', 'alive', '’', 'Sweden'], tags=['SENT_53']),
#  TaggedDocument(words=['UNPO', 'Southern', 'Mongolia', 'Mother', 'Tongue', 'Removed', 'Schools'], tags=['SENT_54']),
#  TaggedDocument(words=['French', 'magazine', '’', 'depiction', 'lawmaker', 'slave', 'chains', 'sparks', 'outrage'], tags=['SENT_55']),
#  TaggedDocument(words=['Baltic', 'states', 'blacklist', 'Lukashenko', 'Belarusian', 'officials'], tags=['SENT_56']),
#  TaggedDocument(words=['Alleged', '‘', 'covidiots', '’', 'force', 'passengers', 'Greece-U.K.', 'flight', 'quarantine'], tags=['SENT_57']),
#  TaggedDocument(words=['Yegor', 'Zhukov', 'Leading', 'Russian', 'opposition', 'blogger', 'beaten'], tags=['SENT_58']),
#  TaggedDocument(words=['Facebook', 'bans', 'QAnon', 'groups', 'dangerous', 'amid', 'surging', 'misinformation'], tags=['SENT_59']),
#  TaggedDocument(words=['Ontario', 'ombudsman', 'blasts', '‘', 'outdated', '’', 'police', 'training', 'tool', 'emphasizes', 'weapons', 'de-escalation', 'despite', 'repeated', 'calls', 'change'], tags=['SENT_60']),
#  TaggedDocument(words=['Facebook', 'Twitter', 'take', 'action', 'Trump', "'s", 'misleading', 'COVID-19', 'posts'], tags=['SENT_61']),
#  TaggedDocument(words=['UK', 'beef', 'exports', 'US', 'resume', '20', 'years'], tags=['SENT_62']),
#  TaggedDocument(words=['Unfavorable', 'Views', 'China', 'Reach', 'Historic', 'Highs', 'Many', 'Countries'], tags=['SENT_63']),
#  TaggedDocument(words=['Trump', 'says', 'declassified', 'documents', 'related', 'Russia', 'Clinton', 'email', 'probes'], tags=['SENT_64']),
#  TaggedDocument(words=['Scientists', 'discover', '24', "'superhabitable", 'planets', 'conditions', 'better', 'life', 'Earth'], tags=['SENT_65']),
#  TaggedDocument(words=['Canada', 'begins', 'accepting', 'Hong', 'Kong', 'pro-democracy', 'activists', 'refugees'], tags=['SENT_66']),
#  TaggedDocument(words=['Billionaires', 'wealth', 'rises', '10.2', 'trillion', 'amid', 'Covid', 'crisis'], tags=['SENT_67']),
#  TaggedDocument(words=['Coronavirus', 'What', "'s", 'happening', 'Canada', 'around', 'world', 'Wednesday'], tags=['SENT_68']),
#  TaggedDocument(words=['Trudeau', 'says', 'Trump', 'incited', 'violent', 'assault', 'democracy'], tags=['SENT_69']),
#  TaggedDocument(words=['About', '80', 'favor', 'canceling', 'postponing', 'Tokyo', 'Olympics', 'summer', 'Kyodo', 'poll'], tags=['SENT_70']),
#  TaggedDocument(words=['Pope', "'s", 'personal', 'doctor', 'dies', 'Covid-19', 'complications'], tags=['SENT_71']),
#  TaggedDocument(words=['First', 'Nations', 'call', 'government', 'end', 'water', 'rights', 'drought'], tags=['SENT_72']),
#  TaggedDocument(words=['UK', 'ministers', 'face', 'legal', 'action', 'lack', 'abortion', 'services', 'Northern', 'Ireland'], tags=['SENT_73']),
#  TaggedDocument(words=['Coronavirus', 'tracked', 'UK', 'new', 'Covid', 'cases', 'per', 'capita', 'country', 'world'], tags=['SENT_74']),
#  TaggedDocument(words=['Israeli', 'Settlers', 'Beat', '78-year-old', 'Palestinian', 'Farmer', 'With', 'Clubs', 'Then', 'They', 'Came', 'Back', 'Attack', 'His', 'Family'], tags=['SENT_75']),
#  TaggedDocument(words=['Japan', 'finds', 'new', 'COVID', 'virus', 'strain', 'distinct', 'UK', 'Africa', 'types'], tags=['SENT_76']),
#  TaggedDocument(words=['Luxembourg', 'calls', 'Trump', "'criminal", "'political", 'pyromaniac', 'sent', 'criminal', 'court'], tags=['SENT_77']),
#  TaggedDocument(words=['Nearly', '45', 'COVID-19', 'cases', 'Ontario', 'considered', 'resolved'], tags=['SENT_78']),
#  TaggedDocument(words=['Coronavirus', 'One', 'seven', 'pregnant', 'women', 'test', 'positive', 'Covid-19', 'study', 'reveals'], tags=['SENT_79']),
#  TaggedDocument(words=["'They", 'brave', 'Briton', '99', 'raises', 'millions', 'health', 'workers'], tags=['SENT_80']),
#  TaggedDocument(words=['Coronavirus', 'German', 'zoo', 'may', 'feed', 'animals'], tags=['SENT_81']),
#  TaggedDocument(words=['World', 'Bank', 'sees', "'huge", 'willingness', 'suspend', 'debt', 'payments', 'poorest', 'countries'], tags=['SENT_82']),
#  TaggedDocument(words=['Good', 'news', 'Taiwan', 'reports', 'zero', 'new', 'coronaviru', '...'], tags=['SENT_83']),
#  TaggedDocument(words=['Singapore', 'Japan', 'cases', 'jump', 'India', 'extends', 'largest', 'lockdown'], tags=['SENT_84']),
#  TaggedDocument(words=['UK', 'urged', 'stop', 'China', 'taking', 'control', 'Imagination', 'Tech', 'lawmaker'], tags=['SENT_85']),
#  TaggedDocument(words=['Covid', '19', 'coronavirus', 'Mutation', 'threatens', 'race', 'develop', 'vaccine'], tags=['SENT_86']),
#  TaggedDocument(words=['USFDA', 'clears', 'four', 'Indian', 'manufacturing', 'plants', '10', 'days'], tags=['SENT_87']),
#  TaggedDocument(words=['Coronavirus', 'Covid', '19', 'Zero', 'new', 'cases', 'today', 'Ashley', 'Bloomfield'], tags=['SENT_88']),
#  TaggedDocument(words=['Missourians', 'tipped', 'county', 'lockdown', 'rule-breakers', 'fear', 'retaliation', 'detail', 'release'], tags=['SENT_89']),
#  TaggedDocument(words=['President', 'Queries', 'Tanzania', 'Coronavirus', 'Kits', 'After', 'Goat', 'Test'], tags=['SENT_90']),
#  TaggedDocument(words=['Canada', 'pledges', '170M', 'develop', 'online', 'mental', 'health', 'services', 'amid', 'coronavirus', 'outbreak'], tags=['SENT_91']),
#  TaggedDocument(words=['72', 'Japan', 'see', 'closure', 'unregulated', 'meat', 'markets', 'key', 'preventing', 'pandemics', 'survey', 'finds'], tags=['SENT_92']),
#  TaggedDocument(words=['Exclusive', 'Internal', 'Chinese', 'report', 'warns', 'Beijing', 'faces', 'Tiananmen-like', 'global', 'backlash', 'virus'], tags=['SENT_93']),
#  TaggedDocument(words=['UK', 'scientists', 'create', 'coronavirus', 'antibody', 'test', "'99.8", 'accuracy', 'results', '35', 'minutes'], tags=['SENT_94']),
#  TaggedDocument(words=['India', 'offers', 'land', 'twice', 'Luxembourg', '’', 'size', 'firms', 'leaving', 'China'], tags=['SENT_95']),
#  TaggedDocument(words=['Trump', 'administration', 'pushing', 'rip', 'global', 'supply', 'chains', 'China', 'officials'], tags=['SENT_96']),
#  TaggedDocument(words=['Italy', 'begins', 'emerge', 'world', "'s", 'longest', 'lockdown'], tags=['SENT_97']),
#  TaggedDocument(words=['Putin', '’', 'popularity', 'collapses', 'coronavirus-ravaged', 'Russia', 'country', 'biggest', 'daily', 'rise', 'Europe'], tags=['SENT_98']),
#  TaggedDocument(words=['‘', 'Time', 'come', '’', 'universal', 'basic', 'income', 'says', 'Sturgeon'], tags=['SENT_99']),
#  TaggedDocument(words=['World', 'leaders', 'pledge', 'fight', 'coronavirus', 'U.S.', 'skips', 'meeting'], tags=['SENT_100']),
#  TaggedDocument(words=['WHO', 'says', 'US', "n't", 'shared', 'evidence', 'linking', 'coronavirus', 'Chinese', 'lab'], tags=['SENT_101']),
#  TaggedDocument(words=['Members', 'Germany', '’', 'ruling', 'coalition', 'tell', 'Trump', 'take', 'U.S.', 'nukes', 'home'], tags=['SENT_102']),
#  TaggedDocument(words=['Viktor', 'Orban', '’', 'Hungary', 'longer', 'democracy', 'Freedom', 'House', 'says'], tags=['SENT_103']),
#  TaggedDocument(words=['Mount', 'Everest', 'Visible', 'From', 'Kathmandu', 'Nepal', 'First', 'Time', 'Living', 'Memory'], tags=['SENT_104']),
#  TaggedDocument(words=['Wuhan', 'bans', 'eating', 'wild', 'animals', 'coronavirus', 'drives', 'crackdown', 'China'], tags=['SENT_105']),
#  TaggedDocument(words=['Annual', 'Hong', 'Kong', 'Tiananmen', 'massacre', 'vigil', 'become', 'city-wide', 'tribute', 'amid', 'Covid-19', 'museum', 'reopens'], tags=['SENT_106']),
#  TaggedDocument(words=['Mike', 'Pompeo', 'attacks', 'China', 'says', "'we", 'stand', 'Australia', '–', 'video'], tags=['SENT_107']),
#  TaggedDocument(words=['Grandmother', 'ordered', 'delete', 'Facebook', 'photos', 'GDPR'], tags=['SENT_108']),
#  TaggedDocument(words=['Boris', 'Johnson', 'drops', 'NHS', 'fee', 'migrant', 'healthcare', 'workers', 'humiliating', 'U-turn', '24', 'hours', 'defending', 'policy'], tags=['SENT_109']),
#  TaggedDocument(words=['China', 'seem', 'understand', 'independence', 'Canada', "'s", 'judiciary', 'Trudeau'], tags=['SENT_110']),
#  TaggedDocument(words=['70', 'Dubai', 'companies', 'expect', 'go', 'business', 'within', 'six', 'months', 'due', 'coronavirus', 'pandemic', 'survey', 'says'], tags=['SENT_111']),
#  TaggedDocument(words=['Spain', 'reports', 'lowest', 'daily', 'death', 'toll', 'two', 'months', '–', 'happened'], tags=['SENT_112']),
#  TaggedDocument(words=['Brazil', 'second-highest', 'number', 'coronavirus', 'cases', 'world', 'US'], tags=['SENT_113']),
#  TaggedDocument(words=["'We", 'go', 'SpaceX', 'cleared', '2', 'huge', 'hurdles', 'toward', 'first', 'rocket', 'launch', 'NASA', 'astronauts', 'space', 'next', 'week'], tags=['SENT_114']),
#  TaggedDocument(words=['Covid', '19', 'coronavirus', 'Jacinda', 'Ardern', 'voted', 'second', 'world', "'s", 'top', '50', 'thinkers'], tags=['SENT_115']),
#  TaggedDocument(words=['New', 'Zealand', 'prime', 'minister', 'course', 'election', 'victory', 'poll'], tags=['SENT_116']),
#  TaggedDocument(words=['Greta', 'Thunberg', 'youth', 'climate', 'protests', 'return'], tags=['SENT_117']),
#  TaggedDocument(words=['Are', 'robot'], tags=['SENT_118']),
#  TaggedDocument(words=['Switzerland', 'voters', 'reject', 'curbs', 'EU', 'immigration', 'TV', 'projection'], tags=['SENT_119']),
#  TaggedDocument(words=['Schools', 'England', 'told', 'use', 'anti-capitalist', 'material', 'teaching'], tags=['SENT_120']),
#  TaggedDocument(words=['Geneva', 'Voters', 'Agree', '25', 'Minimum', 'Hourly', 'Wage'], tags=['SENT_121']),
#  TaggedDocument(words=['European', 'commission', 'appeal', '€13bn', 'Apple', 'tax', 'ruling'], tags=['SENT_122']),
#  TaggedDocument(words=['Sri', 'Lanka', 'returns', 'containers', 'illegal', 'waste', 'Britain', 'Customs'], tags=['SENT_123']),
#  TaggedDocument(words=['Venezuela', '’', 'broken', 'oil', 'industry', 'spewing', 'crude', 'Caribbean', 'Sea'], tags=['SENT_124']),
#  TaggedDocument(words=['World', 'leaders', 'urged', 'ban', 'trade', 'wild', 'animals', 'birds', 'eating', 'prevent', 'pandemics'], tags=['SENT_125']),
#  TaggedDocument(words=['Feminist', 'protesters', 'battle', 'police', 'Mexico', 'City'], tags=['SENT_126']),
#  TaggedDocument(words=['Suicide', 'spike', 'Japan', 'shows', 'mental', 'health', 'toll', 'COVID-19'], tags=['SENT_127']),
#  TaggedDocument(words=['US-inspired', 'rightwing', 'extremism', "'insidious", 'threat', 'Australia', 'study', 'finds'], tags=['SENT_128']),
#  TaggedDocument(words=['France', 'distribute', 'free', 'medical', 'cannabis', 'launch', 'experiment', '2021'], tags=['SENT_129']),
#  TaggedDocument(words=['40', 'Amazon', 'Rainforest', 'Is', 'Tipping', 'Point', 'To', 'Becoming', 'Savanna'], tags=['SENT_130']),
#  TaggedDocument(words=['The', 'United', 'Nations', 'World', 'Food', 'Programme', '2020', 'Nobel', 'Peace', 'Prize'], tags=['SENT_131']),
#  TaggedDocument(words=['Vancouver', 'council', 'approves', '30M', 'plan', 'house', 'homeless', 'people', 'vacant', 'hotels', 'apartment', 'buildings'], tags=['SENT_132']),
#  TaggedDocument(words=['Taiwan', 'president', 'pledge', 'strong', 'defences', 'China', 'tensions', 'rise'], tags=['SENT_133']),
#  TaggedDocument(words=['Israeli', 'Soldiers', 'Raid', 'Palestinian', 'Village', 'Night', 'Terrifying', 'Residents', '–', 'Training', 'Purposes'], tags=['SENT_134']),
#  TaggedDocument(words=['New', 'evidence', 'suggests', 'China', '’', '‘', 'dark', '’', 'vessels', 'poached', 'Galápagos', 'waters'], tags=['SENT_135']),
#  TaggedDocument(words=['Trump', 'administration', 'pulls', 'Open', 'Skies', 'treaty', 'Russia'], tags=['SENT_136']),
#  TaggedDocument(words=['Food', 'brands', 'linked', 'Brazil', 'deforestation'], tags=['SENT_137']),
#  TaggedDocument(words=['Type', 'O', 'blood', 'linked', 'lower', 'COVID', 'risk', 'taking', 'Vitamin', 'D', 'unlikely', 'help'], tags=['SENT_138']),
#  TaggedDocument(words=['German', 'troops', 'suspected', 'running', 'anti-Semitic', 'chat', 'group', 'document'], tags=['SENT_139']),
#  TaggedDocument(words=['Honduran', 'ex-president', 'Zelaya', 'stopped', 'airport', 'bag', 'money'], tags=['SENT_140']),
#  TaggedDocument(words=['Norway', 'makes', 'first', 'discovery', 'highly', 'pathogenic', 'bird', 'flu'], tags=['SENT_141']),
#  TaggedDocument(words=['Chinese', 'President', 'Xi', 'tells', 'army', "'not", 'fear', 'death', "'prepare", 'win', 'wars'], tags=['SENT_142']),
#  TaggedDocument(words=['O', 'kování', 'proti', 'covidu-19', 'bude', 'pro', 'všechny', 'ob', 'zdarma', 'Blatný', 'vyzývá', 'k', 'široké', 'ú', 'asti'], tags=['SENT_143']),
#  TaggedDocument(words=['Government', 'secretly', 'deployed', 'British', 'troops', 'defend', 'Saudi', 'Arabian', 'oil', 'fields'], tags=['SENT_144']),
#  TaggedDocument(words=['Tackling', 'drunken', 'students', 'night', 'teaching', 'day', 'PhD', 'students', 'say', 'exploited'], tags=['SENT_145']),
#  TaggedDocument(words=['French', 'Police', 'Officers', 'In', 'Custody', 'After', 'Video', 'Emerges', 'Of', 'Brutal', 'Beating', 'Of', 'Black', 'Man'], tags=['SENT_146']),
#  TaggedDocument(words=['Prepare', 'sweat', 'Scorching', 'run', 'days', 'high', '40s', 'arrives'], tags=['SENT_147']),
#  TaggedDocument(words=['France', 'protests', 'turn', 'violent', 'people', 'demonstrate', 'new', 'filming', 'law', 'police', 'brutality'], tags=['SENT_148']),
#  TaggedDocument(words=['More', '400', 'lawmakers', '34', 'countries', 'back', "'Make", 'Amazon', 'Pay', 'campaign'], tags=['SENT_149']),
#  TaggedDocument(words=['German', 'court', 'hands', 'historic', 'Syrian', 'torture', 'verdict'], tags=['SENT_150']),
#  TaggedDocument(words=['North', 'Korea', 'hacked', 'Pfizer', 'wants', 'sell', 'bootleg', 'COVID', 'vaccines', 'international', 'black', 'market', 'sources', 'say'], tags=['SENT_151']),
#  TaggedDocument(words=['Ghost', 'particle', 'crashed', 'Antarctica', 'traced', 'back', 'star', 'shredded', 'black', 'hole'], tags=['SENT_152']),
#  TaggedDocument(words=["'Top", 'Secret', 'Saudi', 'documents', 'show', 'Khashoggi', 'assassins', 'used', 'company', 'seized', 'Saudi', 'crown', 'prince'], tags=['SENT_153']),
#  TaggedDocument(words=['Government', 'Canada', 'launches', 'international', 'space', 'program', 'track', 'illegal', 'fishing'], tags=['SENT_154']),
#  TaggedDocument(words=['At', 'least', '2', 'dead', 'PNP', 'PDEA', 'shoot', 'bungled', "'buy-bust", 'operation'], tags=['SENT_155']),
#  TaggedDocument(words=['Hate', 'crimes', '97', 'overall', 'Vancouver', 'last', 'year', 'anti-Asian', 'hate', 'crimes', '717'], tags=['SENT_156']),
#  TaggedDocument(words=['Dozens', 'catch', 'Covid', 'indoor', 'conference', 'hosted', 'founder', 'Covid', 'vaccine', 'company'], tags=['SENT_157']),
#  TaggedDocument(words=['‘', 'Mutual', 'suicide', '’', 'US', 'issues', 'stark', 'warning', 'climate', 'change'], tags=['SENT_158']),
#  TaggedDocument(words=['Ramen-Loving', 'Researcher', 'Discovers', 'Tonkotsu', 'Absorbs', 'Radiation'], tags=['SENT_159']),
#  TaggedDocument(words=['Yemen', 'Faces', 'World', "'s", 'Worst', 'Famine', 'Decades', 'Warns', 'U.N'], tags=['SENT_160']),
#  TaggedDocument(words=['Exhausted', 'COVID-19', 'fight', 'Portuguese', 'nurses', 'want', 'pay', 'applause'], tags=['SENT_161']),
#  TaggedDocument(words=['Saudi', 'heir', 'complicit', 'Khashoggi', 'murder', 'US', 'assessment', 'reportedly', 'finds'], tags=['SENT_162']),
#  TaggedDocument(words=['First', 'successful', 'birth', 'critically', 'endangered', 'Malayan', 'tiger', 'cubs', 'Wildlife', 'Reserves', 'Singapore', '23', 'years'], tags=['SENT_163']),
#  TaggedDocument(words=['Centre', 'opposes', 'same-sex', 'marriage', 'Delhi', 'HC', 'says', 'comparable', '‘', 'Indian', 'family', 'unit', 'concept', '’'], tags=['SENT_164']),
#  TaggedDocument(words=['Biden', 'administration', 'preparing', 'sanction', 'Russia', 'SolarWinds', 'hacks', 'poisoning', 'opposition', 'leader'], tags=['SENT_165']),
#  TaggedDocument(words=['Gorilla', 'loses', 'appetite', 'lions', 'develop', 'cough', 'catching', 'COVID-19', 'Prague', 'Zoo'], tags=['SENT_166']),
#  TaggedDocument(words=['Dutch', 'parliament', 'China', "'s", 'treatment', 'Uighurs', 'genocide'], tags=['SENT_167']),
#  TaggedDocument(words=['Two', 'charged', 'supplying', 'bomb', 'killed', 'Maltese', 'journalist'], tags=['SENT_168']),
#  TaggedDocument(words=['Ukraine', 'disconnect', 'Russia', 'Belarus', '’', 'power', 'systems', 'end', '2023'], tags=['SENT_169']),
#  TaggedDocument(words=['Are', 'robot'], tags=['SENT_170']),
#  TaggedDocument(words=['Alexei', 'Navalny', 'Jailed', 'Putin', 'critic', "'moved", 'Moscow', 'prison'], tags=['SENT_171']),
#  TaggedDocument(words=['6,500', 'Migrant', 'Workers', 'Have', 'Died', 'Qatar', 'Since', 'It', 'Was', 'Named', 'FIFA', 'World', 'Cup', 'Host'], tags=['SENT_172']),
#  TaggedDocument(words=['‘', 'Attempted', 'coup', '’', 'Armenia', 'Turkey', 'Russia', 'European', 'Union', 'respond'], tags=['SENT_173']),
#  TaggedDocument(words=['US', 'military', 'helicopters', 'flying', 'low', 'altitudes', 'downtown', 'Tokyo', 'Mainichi', 'probe'], tags=['SENT_174']),
#  TaggedDocument(words=['I', 'left', 'Britain', 'escape', 'toxic', 'press', 'Prince', 'Harry', 'says'], tags=['SENT_175']),
#  TaggedDocument(words=['U.S.', 'air', 'strikes', 'Syria', 'target', 'Iranian-backed', 'militia', 'Pentagon'], tags=['SENT_176']),
#  TaggedDocument(words=['Exclusive', 'Mexico', "'s", 'president', 'expected', 'ask', 'Biden', 'share', 'U.S.', 'vaccines', 'say', 'sources'], tags=['SENT_177']),
#  TaggedDocument(words=['All', 'spent', 'fuel', 'finally', 'removed', 'reactor', 'Fukushima', 'plant', 'The', 'Asahi', 'Shimbun'], tags=['SENT_178']),
#  TaggedDocument(words=['Crowd', 'Mexico', 'stops', 'gay', 'couple', 'arrested', 'chant', '‘', 'I', '’', 'gay', '’', 'cops'], tags=['SENT_179']),
#  TaggedDocument(words=['Tokyo', 'asks', 'China', 'stop', 'anal', 'swab', 'tests', 'COVID-19', 'Japanese', 'citizens'], tags=['SENT_180']),
#  TaggedDocument(words=['Khashoggi', "'s", 'fiancée', 'says', 'Saudi', 'crown', 'prince', 'punished', '``', 'without', 'delay', "''"], tags=['SENT_181']),
#  TaggedDocument(words=['Three', 'names', 'mysteriously', 'removed', 'Khashoggi', 'intelligence', 'report', 'initial', 'publication'], tags=['SENT_182']),
#  TaggedDocument(words=['UK', 'Supreme', 'Court', 'says', 'Uber', 'drivers', 'independent', 'contractors'], tags=['SENT_183']),
#  TaggedDocument(words=["'This", 'historic', 'Malaysian', 'man', 'wins', 'appeal', 'Islamic', 'gay', 'sex', 'charge'], tags=['SENT_184']),
#  TaggedDocument(words=['Fossil', 'fuel', 'cars', 'make', "'hundreds", 'times', 'waste', 'electric', 'cars'], tags=['SENT_185']),
#  TaggedDocument(words=['China', 'counters', 'Uighur', 'criticism', 'explicit', 'attacks', 'women', 'witnesses'], tags=['SENT_186']),
#  TaggedDocument(words=['China', 'Xinjiang', 'First', 'independent', 'report', 'Uyghur', 'genocide', 'allegations', 'claims', 'evidence', 'Beijing', "'s", "'intent", 'destroy', 'Muslim', 'minorities'], tags=['SENT_187']),
#  TaggedDocument(words=['Reports', 'Myanmar', 'security', 'forces', 'kill', 'least', '34', 'protesters'], tags=['SENT_188']),
#  TaggedDocument(words=["'Everything", 'OK', 'slain', 'Myanmar', 'teen', "'s", 'T-shirt', 'slogan', 'spurs', 'defiance'], tags=['SENT_189']),
#  TaggedDocument(words=['Google', 'Stop', 'Selling', 'Targeted', 'Ads', 'Based', 'Browsing', 'History'], tags=['SENT_190']),
#  TaggedDocument(words=['‘', 'Incel', '’', 'Toronto', 'Van', 'Killer', 'Found', 'Guilty', 'Murdering', '10', 'People'], tags=['SENT_191']),
#  TaggedDocument(words=['The', 'Gulf', 'Stream', 'slowing', "'tipping", 'point', 'could', 'disappear'], tags=['SENT_192']),
#  TaggedDocument(words=['17,000', 'earthquakes', 'hit', 'Iceland', 'past', 'week', 'An', 'eruption', 'could', 'imminent'], tags=['SENT_193']),
#  TaggedDocument(words=['China', 'make', 'Covid', 'anal', 'swabs', 'mandatory', 'foreign', 'arrivals', 'Japan', 'US', 'blasted', '‘', 'humiliating', '’', 'procedure'], tags=['SENT_194']),
#  TaggedDocument(words=['The', 'Majority', 'France', 'Would', 'Legalise', 'Recreational', 'Cannabis'], tags=['SENT_195']),
#  TaggedDocument(words=['Myanmar', "'war", 'zone', 'security', 'forces', 'open', 'fire', 'peaceful', 'protesters', 'killing', '38'], tags=['SENT_196']),
#  TaggedDocument(words=['Stop', 'murdering', 'jailing', 'protestors', 'UN', 'human', 'rights', 'chief', 'tells', 'Myanmar', 'military'], tags=['SENT_197']),
#  TaggedDocument(words=['Hong', 'Kong', 'axed', 'economic', 'freedom', 'index', 'years', 'top', 'spot', 'ranked', '107th', 'part', 'China'], tags=['SENT_198']),
#  TaggedDocument(words=['Irony', 'Saharan', 'dust', 'returns', 'radiation', 'French', 'nuclear', 'tests', '1960s'], tags=['SENT_199']),
#  TaggedDocument(words=['Judge', 'refuses', 'name', 'fame-craving', '‘', 'incel', '’', 'killer', 'convicts', '10', 'murders'], tags=['SENT_200']),
#  TaggedDocument(words=['US', 'decision', 'punish', 'crown', 'prince', 'puts', 'us', 'grave', 'danger', 'Saudi', 'exiles', 'say'], tags=['SENT_201']),
#  TaggedDocument(words=['China', 'breaching', 'every', 'act', 'genocide', 'convention', 'says', 'legal', 'report', 'Uighurs'], tags=['SENT_202']),
#  TaggedDocument(words=['Subscribe', 'read'], tags=['SENT_203']),
#  TaggedDocument(words=['An', 'American', 'Who', 'Fought', 'With', 'Extremists', 'In', 'Ukraine', 'Will', 'Be', 'Extradited', 'To', 'Face', 'Double', 'Murder', 'Charges', 'In', 'Florida'], tags=['SENT_204']),
#  TaggedDocument(words=['Biden', 'send', '4', 'million', 'AstraZeneca', 'vaccine', 'doses', 'Canada', 'Mexico'], tags=['SENT_205']),
#  TaggedDocument(words=['US', 'ties', 'Russia', 'China', 'sink', 'Biden', 'toes', 'tough', 'lines'], tags=['SENT_206']),
#  TaggedDocument(words=['Highest', 'turnout', 'weeks', 'final', 'pre-election', 'protest', 'Netanyahu'], tags=['SENT_207']),
#  TaggedDocument(words=['Delhi-to-Toronto', 'flights', 'bringing', 'Covid', 'cases', 'Canada'], tags=['SENT_208']),
#  TaggedDocument(words=['Half', 'UK', 'adults', 'gotten', 'one', 'dose', 'COVID-19', 'vaccine'], tags=['SENT_209']),
#  TaggedDocument(words=['Revealed', 'grim', 'list', 'sex', 'abuse', 'claims', 'Metropolitan', 'police'], tags=['SENT_210']),
#  TaggedDocument(words=['50,000', 'anti-Netanyahu', 'protesters', 'gather', 'pre-election', 'demonstrations'], tags=['SENT_211']),
#  TaggedDocument(words=['Canadian', 'Conservative', 'party', 'votes', 'recognize', 'climate', 'crisis', 'real'], tags=['SENT_212']),
#  TaggedDocument(words=['Philippines', 'says', '220', 'Chinese', 'militia', 'vessels', 'seen', 'disputed', 'waters', 'month'], tags=['SENT_213']),
#  TaggedDocument(words=['Japan', "'s", 'music', 'school', 'students', 'subject', 'copyright', 'fees', 'teachers', 'high', 'court'], tags=['SENT_214']),
#  TaggedDocument(words=['Three', 'Days', 'Israel', 'Election', 'Tens', 'Thousands', 'Protest', 'Against', 'Netanyahu', 'Across', 'Country'], tags=['SENT_215']),
#  TaggedDocument(words=['Climate', 'fight', "'is", 'undermined', 'social', 'media', "'s", 'toxic', 'reports'], tags=['SENT_216']),
#  TaggedDocument(words=['Number', 'Civilians', 'Slain', 'Junta', '’', 'Forces', 'Grows', 'As', 'High', 'School', 'Student', 'Mother', 'Among', 'Killed'], tags=['SENT_217']),
#  TaggedDocument(words=['In', 'precedent', 'court', 'rules', 'school', 'bar', 'unvaccinated', 'untested', 'worker'], tags=['SENT_218']),
#  TaggedDocument(words=['Coronavirus', 'Suppliers', "'not", 'asked', 'divert', 'PPE', 'England'], tags=['SENT_219']),
#  TaggedDocument(words=['Exclusive', 'France', 'hike', 'crisis', 'response', '10', 'billion', 'euros', '110', 'billion', 'sources'], tags=['SENT_220']),
#  TaggedDocument(words=['Arabic', 'press', 'review', 'Al', 'Jazeera', 'host', 'receives', 'death', 'threats', 'Saudi', 'criticism'], tags=['SENT_221']),
#  TaggedDocument(words=['Coronavirus', "'World", 'faces', 'worst', 'recession', 'since', 'Great', 'Depression'], tags=['SENT_222']),
#  TaggedDocument(words=['Global', 'economy', '2020', 'track', 'sharpest', 'downturn', 'since', '1930s', 'IMF'], tags=['SENT_223']),
#  TaggedDocument(words=['Scientists', 'create', 'mutant', 'enzyme', 'recycles', 'plastic', 'bottles', 'hours'], tags=['SENT_224']),
#  TaggedDocument(words=['Man', 'accidentally', 'ejects', 'fighter', 'jet', 'surprise', 'flight'], tags=['SENT_225']),
#  TaggedDocument(words=['Coronavirus', 'Around', 'half', 'COVID-19', 'deaths', 'care', 'homes'], tags=['SENT_226']),
#  TaggedDocument(words=['Thousands', 'Defy', 'Lockdown', 'At', 'Bandra', 'Station', 'In', 'Mumbai', 'Lathicharged', 'By', 'Cops'], tags=['SENT_227']),
#  TaggedDocument(words=['Austria', 'reopens', 'thousands', 'shops', 'first', 'loosening', 'coronavirus', 'lockdown'], tags=['SENT_228']),
#  TaggedDocument(words=['Special', 'Report', 'Hong', 'Kong', 'judges', 'battle', 'Beijing', 'rule', 'law', 'pandemic', 'chills', 'protests'], tags=['SENT_229']),
#  TaggedDocument(words=['SPECIAL', 'REPORT-Hong', 'Kong', 'judges', 'battle', 'Beijing', 'rule', 'law', 'pandemic', 'chills', 'protests'], tags=['SENT_230']),
#  TaggedDocument(words=['World', '‘', 'certainly', 'seeing', 'peak', '’', 'Covid-19', 'yet', 'says', 'WHO'], tags=['SENT_231']),
#  TaggedDocument(words=['Mafia-linked', 'funeral', 'investigated', 'amid', 'coronavirus', 'lockdown'], tags=['SENT_232']),
#  TaggedDocument(words=['UK', 'pledges', '250', 'million', 'WHO', 'charities', 'help', 'slow', 'spread', 'coronavirus'], tags=['SENT_233']),
#  TaggedDocument(words=['China', 'moves', 'block', 'new', 'virus', 'flare-up', 'Russian', 'border'], tags=['SENT_234']),
#  TaggedDocument(words=['MPs', 'summon', 'China-owned', 'firm', 'execs', 'security', 'concerns'], tags=['SENT_235']),
#  TaggedDocument(words=['WHO', 'officials', 'say', "'s", 'unclear', 'whether', 'recovered', 'coronavirus', 'patients', 'immune', 'second', 'infection'], tags=['SENT_236']),
#  TaggedDocument(words=['Apple', 'launches', 'site', 'show', 'coronavirus', 'lockdowns', 'affect', 'movement'], tags=['SENT_237']),
#  TaggedDocument(words=['Exclusive', 'Nurses', 'Mexico', 'hospital', 'hit', 'coronavirus', 'say', 'told', 'avoid', 'masks'], tags=['SENT_238']),
#  TaggedDocument(words=['Arsonists', 'attack', 'phone', 'mast', 'serving', 'NHS', 'Nightingale', 'hospital'], tags=['SENT_239']),
#  TaggedDocument(words=['Oil', 'gains', 'U.S.', 'shale', 'production', 'set', 'fall', 'sharply'], tags=['SENT_240']),
#  TaggedDocument(words=['Iran', 'coronavirus', 'fatalities', 'drop', 'double', 'figures', 'first', 'time', 'month'], tags=['SENT_241']),
#  TaggedDocument(words=['Australian', 'cardinal', 'links', 'corruption', 'child', 'abuse', 'charges'], tags=['SENT_242']),
#  TaggedDocument(words=['North', 'Korea', 'fires', 'barrage', 'missiles', 'ground', 'air'], tags=['SENT_243']),
#  TaggedDocument(words=['Coronavirus', '25,000', 'beds', 'needed', 'Covid-19', 'patients', 'months', 'come', 'secret', 'NHS', 'report', 'reveals'], tags=['SENT_244']),
#  TaggedDocument(words=['``', 'It', "'s", 'early', 'ease', 'restrictions', "''"], tags=['SENT_245']),
#  TaggedDocument(words=['Five', 'B-52s', 'Six', 'KC-135s', 'Along', 'With', 'RQ-4', 'MQ-4C', 'MH-60S', 'Take', 'Part', 'Elephant', 'Walk', 'Andersen', 'AFB', 'Guam'], tags=['SENT_246']),
#  TaggedDocument(words=['New', 'study', 'suggests', 'COVID-19', 'hopped', 'dogs', 'humans', 'Here', "'s", 'skeptical'], tags=['SENT_247']),
#  TaggedDocument(words=['IMF', 'approves', 'debt', 'relief', '25', 'poor', 'countries'], tags=['SENT_248']),
#  TaggedDocument(words=['Despite', 'COVID', 'Amazon', 'deforestation', 'races', 'higher'], tags=['SENT_249']),
#  TaggedDocument(words=['338Canada', 'Canadians', 'overwhelmingly', 'satisfied', 'governments', 'COVID-19', 'responses'], tags=['SENT_250']),
#  TaggedDocument(words=["'Mixed", 'picture', 'Europe', 'COVID-19', 'vaccine', 'least', '12', 'months', 'WHO'], tags=['SENT_251']),
#  TaggedDocument(words=['China', 'Reports', '169', 'New', 'Coronavirus', 'Cases', '—', 'Highest', 'In', '5', 'Weeks'], tags=['SENT_252']),
#  TaggedDocument(words=['Virgin', 'Australia', 'goes', 'trading', 'halt', 'ponders', 'financial', 'options', 'stay', 'afloat'], tags=['SENT_253']),
#  TaggedDocument(words=['India', 'extends', 'world', "'s", 'biggest', 'lockdown', 'ignites', 'protest', 'migrant', 'workers'], tags=['SENT_254']),
#  TaggedDocument(words=['Child', 'sex', 'abuse', 'Pakistan', '’', 'religious', 'schools', 'endemic'], tags=['SENT_255']),
#  TaggedDocument(words=['Indian', 'Police', 'Force', 'Tourists', 'Violating', 'Lockdown', 'To', 'Write', 'I', 'Am', 'Very', 'Sorry', '500', 'Times'], tags=['SENT_256']),
#  TaggedDocument(words=['Thai', 'economy', 'could', 'lose', '40', 'billion', 'virus', 'crisis', 'goes', 'beyond', 'second', 'quarter'], tags=['SENT_257']),
#  TaggedDocument(words=['Doctors', 'worry', 'populous', 'Indian', 'state', 'struggles', 'coronavirus', 'tests'], tags=['SENT_258']),
#  TaggedDocument(words=['Austria', 'reopens', 'small', 'shops', 'parks', 'coronavirus', 'lockdown', 'relaxed'], tags=['SENT_259']),
#  TaggedDocument(words=['Spain', 'Austria', 'ease', 'coronavirus', 'curbs', 'U.S.', 'debates', 'risks'], tags=['SENT_260']),
#  TaggedDocument(words=['UK', 'missed', 'three', 'chances', 'join', 'EU', 'scheme', 'bulk-buy', 'PPE'], tags=['SENT_261']),
#  TaggedDocument(words=['Scientists', 'discover', '‘', 'extremely', 'unexpected', '’', 'gecko', 'species', 'immediately', 'warn', 'threat', 'extinction', 'humans'], tags=['SENT_262']),
#  TaggedDocument(words=['Prominent', 'ulema', 'say', 'lockdown', 'applicable', 'mosques', 'congregational', 'prayers', 'begin'], tags=['SENT_263']),
#  TaggedDocument(words=['UP', 'woman', 'throws', '5', 'kids', 'river', 'jumps', 'Then', 'changes', 'mind'], tags=['SENT_264']),
#  TaggedDocument(words=['IMF', 'provide', 'debt', 'relief', 'help', '25', 'countries', 'deal', 'pandemic'], tags=['SENT_265']),
#  TaggedDocument(words=['3', '10', 'Canadians', '’', 'pay', 'bills', 'lost', 'job', 'due', 'coronavirus', 'per', 'Ipsos', 'survey'], tags=['SENT_266']),
#  TaggedDocument(words=['Libya', 'Tripoli', "gov't", 'retakes', 'three', 'cities', 'Haftar', "'s", 'forces'], tags=['SENT_267']),
#  TaggedDocument(words=['China', 'Limited', 'Mekong', '’', 'Flow', 'Other', 'Countries', 'Suffered', 'Drought'], tags=['SENT_268']),
#  TaggedDocument(words=['Britain', 'remain', 'lockdown', 'till', 'least', 'May', '7', 'Times'], tags=['SENT_269']),
#  TaggedDocument(words=['Ebola', 'drug', 'infiltrate', 'trick', 'coronavirus', 'inside', 'Alberta', 'study', 'suggests'], tags=['SENT_270']),
#  TaggedDocument(words=['India', "'s", 'Modi', 'extends', 'nationwide', 'coronavirus', 'lockdown', 'May', '3'], tags=['SENT_271']),
#  TaggedDocument(words=['Japan', 'minister', 'Paris', 'accord', 'threat', 'coronavirus', 'trumps', 'climate', 'change'], tags=['SENT_272']),
#  TaggedDocument(words=['Bats', 'may', 'pose', 'higher', 'virus', 'risk', 'species'], tags=['SENT_273']),
#  TaggedDocument(words=['UK', 'PM', 'Johnson', 'continues', 'recovery', 'COVID-19'], tags=['SENT_274']),
#  TaggedDocument(words=['Coronavirus', 'Austria', 'Italy', 'reopen', 'shops', 'lockdown', 'eased'], tags=['SENT_275']),
#  TaggedDocument(words=['Wildfires', "'edge", 'closer', 'Chernobyl', 'nuclear', 'plant'], tags=['SENT_276']),
#  TaggedDocument(words=['Libya', 'rogue', 'warlord', 'Haftar', 'pounds', 'Tripoli', 'suffering', 'huge', 'lo'], tags=['SENT_277']),
#  TaggedDocument(words=['George', 'Pell', 'says', "'culture", 'wars', 'contributed', 'wrongfully', 'jailed', 'child', 'sexual', 'abuse'], tags=['SENT_278']),
#  TaggedDocument(words=['Coronavirus', 'No', '‘', 'Plan', 'B', '’', 'another', 'Olympic', 'postponement', 'organizers', 'say'], tags=['SENT_279']),
#  TaggedDocument(words=['Wildfires', "'edge", 'closer', 'Chernobyl', 'nuclear', 'plant'], tags=['SENT_280']),
#  TaggedDocument(words=['Fearful', 'COVID-19', 'return', 'Beijing', 'turns', 'virtual', 'fortress'], tags=['SENT_281']),
#  TaggedDocument(words=['Poles', 'protest', 'move', 'restrict', 'abortion', 'access'], tags=['SENT_282']),
#  TaggedDocument(words=['IMF', 'says', 'world', "'very", 'likely', 'experience', 'worst', 'recession', 'since', '1930s'], tags=['SENT_283']),
#  TaggedDocument(words=['Small', 'Chloroquine', 'Study', 'Halted', 'Over', 'Risk', 'Fatal', 'Heart', 'Complications'], tags=['SENT_284']),
#  TaggedDocument(words=['French', 'court', 'faults', 'Amazon', 'virus', 'safety', 'limits', 'deliveries'], tags=['SENT_285']),
#  TaggedDocument(words=['Facebook', 'suing', 'Israeli', 'spyware', 'company', 'allegedly', 'hacking', 'WhatsApp', 'Now', 'company', 'says', 'Facebook', 'tried', 'buy', 'spyware', '2017'], tags=['SENT_286']),
#  TaggedDocument(words=['Emergency', 'Declared', 'In', 'Japanese', 'Prefecture', 'Hit', 'By', '2nd', 'Wave', 'Of', 'Coronavirus', 'Infections'], tags=['SENT_287']),
#  TaggedDocument(words=['One', 'third', 'NHS', 'staff', 'tested', 'UK', 'coronavirus'], tags=['SENT_288']),
#  TaggedDocument(words=["'Unacceptable", 'Nigeria', 'condemns', 'treatment', 'citizens', 'China'], tags=['SENT_289']),
#  TaggedDocument(words=['Covid-19', 'Waiter', 'food', 'handler', "'obvious", 'point', 'transmission', 'Ruby', 'Princess'], tags=['SENT_290']),
#  TaggedDocument(words=['South', 'Africa', "'s", 'Ramaphosa', 'blasts', "'despicable", 'crime', 'wave', 'coronavirus', 'lockdown'], tags=['SENT_291']),
#  TaggedDocument(words=['Coronavirus', '10', 'times', 'deadly', 'swine', 'flu', 'says', 'WHO'], tags=['SENT_292']),
#  TaggedDocument(words=['Wildfires', "'edge", 'closer', 'Chernobyl', 'nuclear', 'plant'], tags=['SENT_293']),
#  TaggedDocument(words=['Everything', 'On', 'Coronavirus', 'Contact', 'Tracing', 'Program', 'Apple', 'Google'], tags=['SENT_294']),
#  TaggedDocument(words=['US', 'flexes', 'military', 'might', 'front', 'Russian', 'forces', 'F-35', 'flight', 'Syria', 'photos'], tags=['SENT_295']),
#  TaggedDocument(words=['UK', 'spy', 'agencies', 'urge', 'China', 'rethink', 'Covid-19', 'crisis'], tags=['SENT_296']),
#  TaggedDocument(words=['Putin', 'coronavirus', 'situation', 'Russia', 'changing', 'better'], tags=['SENT_297']),
#  TaggedDocument(words=['Mexico', 'registers', '5,014', 'cases', 'coronavirus', '332', 'deaths', 'health', 'ministry'], tags=['SENT_298']),
#  TaggedDocument(words=['Travellers', 'denied', 'refunds', 'pandemic', 'may', 'little-known', 'option', 'getting', 'money', 'back'], tags=['SENT_299']),
#  TaggedDocument(words=['Top', 'U.S.', 'general', 'resists', 'Trump', 'administration', 'efforts', 'provoke', 'war', 'Iran', 'Mondoweiss'], tags=['SENT_300']),
#  TaggedDocument(words=['Atalanta', 'vs', 'Valencia', 'linked', 'accelerating', 'coronavirus', 'spread'], tags=['SENT_301']),
#  TaggedDocument(words=['Boris', 'Johnson', "'s", 'government', 'reportedly', 'furious', 'China', 'believes', 'could', '40', 'times', 'coronavirus', 'cases', 'claims'], tags=['SENT_302']),
#  TaggedDocument(words=['Toyota', 'Gearing', 'Up', 'To', 'Build', 'Ventilators', 'And', 'Face', 'Shields', 'As', 'Mercedes', 'Offers', 'Use', 'Of', '3D', 'Printers'], tags=['SENT_303']),
#  TaggedDocument(words=['Donald', 'Trump', 'sends', '200', 'ventilators', 'UK', 'London', 'called', 'say', "'needed", 'desperately'], tags=['SENT_304']),
#  TaggedDocument(words=['Iran', '‘', 'hides', '500,000', 'virus', 'cases', '’', 'says', 'member', 'country', '’', 'anti-virus', 'taskforce'], tags=['SENT_305']),
#  TaggedDocument(words=['Are', 'robot'], tags=['SENT_306']),
#  TaggedDocument(words=['‘', 'There', 'Will', 'Be', 'Mass', 'Starvation', '’', 'Moscow', 'Opposition', 'Warns', 'Mayor', 'Coronavirus', 'Closes', 'Businesses'], tags=['SENT_307']),
#  TaggedDocument(words=['Trudeau', 'vows', "'no", 'corners', 'cut', 'accepting', 'masks', 'supplies', 'China'], tags=['SENT_308']),
#  TaggedDocument(words=['Endangered', 'sea', 'turtles', 'hatch', 'Brazil', "'s", 'deserted', 'beaches'], tags=['SENT_309']),
#  TaggedDocument(words=['Edward', 'Snowden', 'says', 'COVID-19', 'could', 'give', 'governments', 'invasive', 'new', 'data-collection', 'powers', 'could', 'last', 'long', 'pandemic'], tags=['SENT_310']),
#  TaggedDocument(words=['UN', 'Environment', 'Chief', 'Warns', 'Nature', 'Sending', 'Us', 'Message', 'Through', 'The', 'Coronavirus', 'Pandemic'], tags=['SENT_311']),
#  TaggedDocument(words=["'So", 'easy', 'I', 'thought', 'fake', 'CRA', '’', 'CERB', 'system', 'gets', 'stellar', 'reviews', 'first', 'days', 'operation'], tags=['SENT_312']),
#  TaggedDocument(words=['Wimbledon', 'paid', 'pandemic', 'insurance', 'almost', '20', 'years', 'Now', '’', 'getting', '141', 'million'], tags=['SENT_313']),
#  TaggedDocument(words=['Pope', 'condemns', 'trying', 'make', 'quick', 'buck', 'coronavirus'], tags=['SENT_314']),
#  TaggedDocument(words=['US', 'intelligence', 'warned', 'November', 'coronavirus', 'spreading', 'China', 'could', "'cataclysmic", 'event', 'report'], tags=['SENT_315']),
#  TaggedDocument(words=['Ontario', 'passes', 'emergency', 'order', 'allowing', 'pot', 'shops', 'deliver', 'offer', 'pickup'], tags=['SENT_316']),
#  TaggedDocument(words=['Coronavirus', 'Lack', 'PPE', '‘', 'shocking', 'indictment', '’', 'government', '’', 'handling', 'crisis', 'doctors', '’', 'leaders', 'say'], tags=['SENT_317']),
#  TaggedDocument(words=['5G', 'protesters', 'sabotage', 'Dutch', 'phone', 'towers'], tags=['SENT_318']),
#  TaggedDocument(words=['127', 'European', 'politicians', 'back', 'Taiwan', '’', '...'], tags=['SENT_319']),
#  TaggedDocument(words=['Spain', 'sets', 'back-to-work', 'guidelines', 'coronavirus', 'death', 'rate', 'slows'], tags=['SENT_320']),
#  TaggedDocument(words=['Google', 'banned', 'Zoom', 'app', 'employee', 'computers', '‘', 'security', 'vulnerabilities', '’'], tags=['SENT_321']),
#  TaggedDocument(words=['Oldest', 'ever', 'piece', 'string', 'made', 'Neanderthals', '50,000', 'years', 'ago'], tags=['SENT_322']),
#  TaggedDocument(words=['South', 'Korea', 'reports', 'recovered', 'coronavirus', 'patients', 'testing', 'positive'], tags=['SENT_323']),
#  TaggedDocument(words=['WHO', 'warns', 'dangers', 'premature', 'lifting', 'Covid-19', 'restrictions'], tags=['SENT_324']),
#  TaggedDocument(words=['Coronavirus', 'survive', 'long', 'exposure', 'high', 'temperature', 'threat', 'lab', 'staff', 'around', 'world', 'paper'], tags=['SENT_325']),
#  TaggedDocument(words=['Coronavirus', 'One', 'five', 'deaths', 'linked', 'virus'], tags=['SENT_326']),
#  TaggedDocument(words=['Coronavirus', '10', 'times', 'deadly', 'swine', 'flu', 'says', 'WHO'], tags=['SENT_327']),
#  TaggedDocument(words=["'Everyone", 'wants', 'Rapid', 'COVID-19', 'test', 'kits', 'made', 'Canada', 'approved', 'use'], tags=['SENT_328']),
#  TaggedDocument(words=['Coronavirus', 'closes', 'meat', 'plants', 'Canada', 'United', 'States', 'world', "'s", 'largest', 'pork', 'producer', 'warns', 'shortages'], tags=['SENT_329']),
#  TaggedDocument(words=['Erik', 'Prince', 'Offered', 'Lethal', 'Services', 'Russian', 'Mercenary', 'Firm'], tags=['SENT_330']),
#  TaggedDocument(words=['Brazil', 'likely', '12', 'times', 'coronavirus', 'cases', 'official', 'count', 'study', 'finds'], tags=['SENT_331']),
#  TaggedDocument(words=['Anti-Corbyn', 'Labour', 'officials', 'worked', 'lose', 'general', 'election', 'oust', 'leader', 'leaked', 'dossier', 'finds'], tags=['SENT_332']),
#  TaggedDocument(words=['Iceland', 'finds', 'half', 'citizens', 'coronavirus', 'shown', 'symptoms'], tags=['SENT_333']),
#  TaggedDocument(words=['Universities', 'brace', 'huge', 'losses', 'foreign', 'students', 'drop'], tags=['SENT_334']),
#  TaggedDocument(words=['Coronavirus', 'France', 'extends', 'lockdown', '11', 'May'], tags=['SENT_335']),
#  TaggedDocument(words=['McDonald', "'s", 'apologized', 'restaurant', 'Guangzhou', 'China', 'refused', 'service', 'black', 'customers'], tags=['SENT_336']),
#  TaggedDocument(words=['Scientists', 'Have', 'Reported', 'The', 'First', 'Case', 'Of', 'The', 'Coronavirus', 'Spreading', 'From', 'A', 'Dead', 'Body'], tags=['SENT_337']),
#  TaggedDocument(words=['Growth', 'surveillance', 'may', 'hard', 'scale', 'back', 'pandemic', 'experts', 'say'], tags=['SENT_338']),
#  TaggedDocument(words=['Putin', '’', 'Bleak', 'Covid-19', 'Admission', '‘', 'We', 'Don', '’', 'Have', 'Much', 'Brag', 'About', '’'], tags=['SENT_339']),
#  TaggedDocument(words=['Taiwan', 'reports', 'new', 'coronavirus', 'cases', 'first', 'time', 'month'], tags=['SENT_340']),
#  TaggedDocument(words=['The', 'world', 'risks', 'surge', 'measles', 'deaths', '100', 'million', 'children', 'set', 'miss', 'vaccines', 'due', 'coronavirus'], tags=['SENT_341']),
#  TaggedDocument(words=['Coronavirus', 'Older', 'people', "'airbrushed", 'virus', 'figures'], tags=['SENT_342']),
#  TaggedDocument(words=['Exclusive', 'Nurses', 'Mexico', 'hospital', 'hit', 'coronavirus', 'say', 'told', 'avoid', 'masks'], tags=['SENT_343']),
#  TaggedDocument(words=['Amazon', 'fires', 'two', 'employees', 'critical', 'warehouse', 'working', 'conditions'], tags=['SENT_344']),
#  TaggedDocument(words=['A', '99-year-old', 'World', 'War', 'II', 'veteran', 'raises', '2.8', 'million', 'UK', 'health-care', 'workers', 'amid', 'coronavirus'], tags=['SENT_345']),
#  TaggedDocument(words=['Lego', 'producing', '13,000', 'face', 'visors', 'day', 'healthcare', 'workers', 'amid', 'coronavirus', 'pandemic'], tags=['SENT_346']),
# ...
#  TaggedDocument(words=['Coronavirus', 'Boris', 'Johnson', 'says', 'UK', "'turning", 'tide', 'time', 'ease', 'lockdown'], tags=['SENT_890']),
#  TaggedDocument(words=['Chinese', 'internet', 'users', 'uploaded', 'coronavirus', 'memories', 'GitHub', 'arrested'], tags=['SENT_891']),
#  TaggedDocument(words=['In', 'France', 'Amazon', 'loses', 'court', 'appeal', 'must', 'stop', 'selling', 'nonessential', 'items', 'protect', 'workers'], tags=['SENT_892']),
#  TaggedDocument(words=['First', 'wild', 'stork', 'chicks', 'hatch', 'UK', 'centuries', 'poised', 'emerge'], tags=['SENT_893']),
#  TaggedDocument(words=['Richard', 'Branson', 'races', 'find', 'Virgin', 'Atlantic', 'buyer'], tags=['SENT_894']),
#  TaggedDocument(words=['German', 'minister', 'backs', 'creating', 'legal', 'right', 'work', 'home'], tags=['SENT_895']),
#  TaggedDocument(words=['Chinese', 'Government', 'official', 'slams', 'Australia', "'s", 'push', 'investigation', 'coronavirus', 'outbreak'], tags=['SENT_896']),
#  TaggedDocument(words=['Climate', 'change', 'World', 'must', "n't", 'forget', "'deeper", 'emergency'], tags=['SENT_897']),
#  TaggedDocument(words=['China', 'seizes', '89', 'million', 'shoddy', 'face', 'masks'], tags=['SENT_898']),
#  TaggedDocument(words=['Top', 'Russian', 'doctor', '‘', 'falls', '’', 'fifth', 'floor', 'window', '‘', 'call', 'bosses', 'complaining', 'lack', 'PPE', 'medics', '’', '–', 'The', 'Sun'], tags=['SENT_899']),
#  TaggedDocument(words=['Psychedelic', 'mushrooms', 'depression', "'This", 'one', 'changed', 'things'], tags=['SENT_900']),
#  TaggedDocument(words=['Clergy', 'criticise', 'tax-haven', 'firms', 'seeking', 'coronavirus', 'cash'], tags=['SENT_901']),
#  TaggedDocument(words=['Silence', 'golden', 'whales', 'lockdown', 'reduces', 'ocean', 'noise'], tags=['SENT_902']),
#  TaggedDocument(words=['China', 'says', 'Hong', 'Kong', 'never', 'calm', 'unless', 'violent', 'protesters', 'removed'], tags=['SENT_903']),
#  TaggedDocument(words=['US', 'South', 'Korean', 'spies', 'believe', 'Kim', 'Jong', 'Un', 'dead', 'satellites', 'pictured', 'train', 'elite', 'coastal', 'resort'], tags=['SENT_904']),
#  TaggedDocument(words=['Right-wing', 'voices', 'primarily', 'responsible', 'spreading', 'coronavirus', 'misinformation', 'report', 'finds'], tags=['SENT_905']),
#  TaggedDocument(words=['This', 'Japanese', 'Island', 'Lifted', 'Its', 'Coronavirus', 'Lockdown', 'Too', 'Soon', 'Became', 'Warning', 'World'], tags=['SENT_906']),
#  TaggedDocument(words=['Saudi', 'Arabia', 'ends', 'death', 'penalty', 'children', 'public', 'floggings'], tags=['SENT_907']),
#  TaggedDocument(words=['Belgians', 'urged', 'eat', 'frites', 'twice', 'week', 'deplete', 'coronavirus', 'potato', 'mountain'], tags=['SENT_908']),
#  TaggedDocument(words=['Coronavirus', 'fears', 'prompt', 'new', 'fines', 'deliberately', 'coughing', 'sneezing', 'spitting', 'frontline', 'workers', 'Queensland'], tags=['SENT_909']),
#  TaggedDocument(words=["'Filthy", 'bloody', 'business', 'Poachers', 'kill', 'animals', 'coronavirus', 'crushes', 'tourism', 'Africa'], tags=['SENT_910']),
#  TaggedDocument(words=['Climate', 'crisis', 'Releasing', 'bison', 'reindeer', 'horses', 'Arctic', 'would', 'slow', 'warming', 'say', 'scientists'], tags=['SENT_911']),
#  TaggedDocument(words=['China', 'threatens', 'halt', 'medical', 'supplies', 'afte', '...'], tags=['SENT_912']),
#  TaggedDocument(words=['Nurses', 'Quit', 'En', 'Masse', 'From', 'Russia', '’', 'Top', 'Coronavirus', 'Hospital', 'Reports'], tags=['SENT_913']),
#  TaggedDocument(words=['These', 'Uighur', 'Journalists', 'Are', 'Investigating', 'Fate', '1', 'Million', 'Muslims', 'China'], tags=['SENT_914']),
#  TaggedDocument(words=['Identifying', 'FSB', '’', 'Elusive', '“', 'Elbrus', '”', 'From', 'MH17', 'To', 'Assassinations', 'In', 'Europe'], tags=['SENT_915']),
#  TaggedDocument(words=['Problem', 'gamblers', 'say', 'coronavirus', 'lockdown', 'providing', 'relief', 'addiction'], tags=['SENT_916']),
#  TaggedDocument(words=['German', 'doctors', 'pose', 'naked', 'protest', 'PPE', 'shortages'], tags=['SENT_917']),
#  TaggedDocument(words=['Climate', 'crisis', 'Sweden', 'closes', 'last', 'coal-fired', 'power', 'station', 'two', 'years', 'ahead', 'schedule'], tags=['SENT_918']),
#  TaggedDocument(words=['Iceland', '’', 'killing', 'whales', 'year'], tags=['SENT_919']),
#  TaggedDocument(words=['Meteorologists', 'say', '2020', 'course', 'hottest', 'year', 'since', 'records', 'began'], tags=['SENT_920']),
#  TaggedDocument(words=['China', 'video', 'Pregnant', 'woman', 'turned', 'away', 'two', 'hospitals', 'Guangzhou', "n't", 'treat', 'Africans'], tags=['SENT_921']),
#  TaggedDocument(words=['Brazil', "'s", 'Supreme', 'Court', 'authorizes', 'investigation', 'Bolsonaro'], tags=['SENT_922']),
#  TaggedDocument(words=['Prague', "'s", 'mayor', 'critic', 'Russia', 'police', 'protection', 'magazine', 'alleged', 'Russian', 'assassin', 'entered', 'country', 'kill'], tags=['SENT_923']),
#  TaggedDocument(words=['Lithuanian', 'capital', 'turned', 'vast', 'open-air', 'cafe'], tags=['SENT_924']),
#  TaggedDocument(words=['Third', 'Russian', 'doctor', 'plunges', 'coronavirus', 'hospital', 'window'], tags=['SENT_925']),
#  TaggedDocument(words=['‘', 'We', 'eve', 'genocide', '’', 'Brazil', 'urged', 'save', 'Amazon', 'tribes', 'Covid-19'], tags=['SENT_926']),
#  TaggedDocument(words=['Pope', 'says', 'coronavirus', 'vaccine', 'must', 'shared', 'worldwide'], tags=['SENT_927']),
#  TaggedDocument(words=['China', 'threatens', 'economic', 'consequences', 'Australia', 'launches', 'investigation', 'Beijing', "'s", 'handling', 'coronavirus'], tags=['SENT_928']),
#  TaggedDocument(words=['Australia', 'called', "'gum", 'stuck', 'China', "'s", 'shoe', 'state', 'media', 'coronavirus', 'investigation', 'stoush'], tags=['SENT_929']),
#  TaggedDocument(words=['Downing', 'Street', 'bars', 'Sunday', 'Times', 'journalists', 'posing', 'questions', 'coronavirus', 'briefing'], tags=['SENT_930']),
#  TaggedDocument(words=['6', 'monkeys', 'given', 'experimental', 'coronavirus', 'vaccine', 'Oxford', 'catch', 'COVID-19', 'heavy', 'exposure', 'raising', 'hopes', 'human', 'vaccine'], tags=['SENT_931']),
#  TaggedDocument(words=['Russians', '’', 'Trust', 'Putin', 'Hits', '14-Year', 'Low', '–', 'State', 'Poll'], tags=['SENT_932']),
#  TaggedDocument(words=['Coronavirus', 'Pandemics', 'worse', 'frequent', 'unless', 'stop', 'exploiting', 'Earth', 'animals', 'top', 'scientists', 'warn'], tags=['SENT_933']),
#  TaggedDocument(words=['Coronavirus-themed', 'game', 'banned', 'China'], tags=['SENT_934']),
#  TaggedDocument(words=['Waiting', 'life', 'return', 'pre-pandemic', 'normal', "'It", 'wo', "n't", 'PM', 'says'], tags=['SENT_935']),
#  TaggedDocument(words=['Coronavirus', 'Hong', 'Kong', 'records', 'new', 'cases', 'Sunday', 'marking', '14', 'straight', 'days', 'without', 'local', 'infection'], tags=['SENT_936']),
#  TaggedDocument(words=['Germany', "'s", 'coronavirus', 'infection', 'rate', 'edges', 'higher', 'lockdown', 'measures', 'eased'], tags=['SENT_937']),
#  TaggedDocument(words=['Australia', 'asks', 'China', 'explain', "'economic", 'coercion', 'threat', 'coronavirus', 'row'], tags=['SENT_938']),
#  TaggedDocument(words=['No', 'COVID-19', 'bailouts', 'firms', 'use', 'tax', 'havens', 'Prime', 'Minister', 'Justin', 'Trudeau', 'says'], tags=['SENT_939']),
#  TaggedDocument(words=['Taiwan', 'pushes', 'Australia', 'back', 'World', 'Health', 'Organisation', 'tilt'], tags=['SENT_940']),
#  TaggedDocument(words=['Khashoggi', 'fiancée', 'calls', 'Premier', 'League', 'block', 'Newcastle', 'Saudi', 'takeover'], tags=['SENT_941']),
#  TaggedDocument(words=['University', 'Oxford', 'cuts', 'ties', 'fossil', 'fuels', 'industry'], tags=['SENT_942']),
#  TaggedDocument(words=['Scientists', 'uncover', 'evidence', 'coronavirus', 'could', 'trigger', 'diabetes', 'healthy', 'adults'], tags=['SENT_943']),
#  TaggedDocument(words=['Coronavirus', 'Almost', 'half', 'doctors', 'buy', 'PPE', 'rely', 'donations', 'survey', 'shows'], tags=['SENT_944']),
#  TaggedDocument(words=['Finland', 'rejects', '104,000', 'kilos', 'Israeli', 'oranges', 'banned', 'pesticide'], tags=['SENT_945']),
#  TaggedDocument(words=['Netherlands', 'changes', 'name', 'representative', '...'], tags=['SENT_946']),
#  TaggedDocument(words=['Zijin', 'warns', 'Papua', 'New', 'Guinea', 'China', 'anger', 'end', 'gold', 'mine', 'lease'], tags=['SENT_947']),
#  TaggedDocument(words=['LEAD', 'Recovered', 'virus', 'patients', 'retest', 'positive', 'due', "'dead", 'virus', 'fragments', 'experts'], tags=['SENT_948']),
#  TaggedDocument(words=['‘', 'Mask', 'diplomacy', '’', 'Taiwan', 'donates', 'half', 'million', 'masks', 'Canada', 'appeal', 'closer', 'ties'], tags=['SENT_949']),
#  TaggedDocument(words=['The', 'largest', 'Arctic', 'ozone', 'hole', 'ever', 'recorded', 'closed'], tags=['SENT_950']),
#  TaggedDocument(words=['UN', 'chief', '’', 'use', 'taxpayer', 'cash', 'rescue', 'carbon-intensive', 'industries'], tags=['SENT_951']),
#  TaggedDocument(words=["'So", 'Bolsonaro', 'shrugs', 'Brazil', "'s", 'rising', 'coronavirus', 'death', 'toll'], tags=['SENT_952']),
#  TaggedDocument(words=['Coronavirus', 'Outcry', 'Spanish', 'beach', 'sprayed', 'bleach'], tags=['SENT_953']),
#  TaggedDocument(words=['Green', 'stimulus', 'Pakistan', 'sets', 'virus-idled', 'work', 'planting', 'trees'], tags=['SENT_954']),
#  TaggedDocument(words=['Exclusive', 'Amazon', 'turns', 'Chinese', 'firm', 'U.S.', 'blacklist', 'meet', 'thermal', 'camera', 'needs'], tags=['SENT_955']),
#  TaggedDocument(words=['Sweden', 'plans', 'ask', 'European', 'Union', 'investigate', 'origin', 'Covid-19', 'likely', 'straining', 'relations', 'China'], tags=['SENT_956']),
#  TaggedDocument(words=['Brazil', 'president', 'still', 'telling', 'people', "'ignore", 'lockdown', 'despite', '6,000', 'coronavirus', 'deaths'], tags=['SENT_957']),
#  TaggedDocument(words=["'Stay", 'home', 'dance', 'us', 'Ghana', "'s", 'dancing', 'pallbearers', 'urge', 'social', 'distancing'], tags=['SENT_958']),
#  TaggedDocument(words=['Canada', 'set', 'ban', 'assault-style', 'weapons', 'including', 'AR-15', 'gun', 'used', 'Polytechnique', 'massacre'], tags=['SENT_959']),
#  TaggedDocument(words=['Thunberg', 'donates', '100,000', 'support', 'children', 'pandemic'], tags=['SENT_960']),
#  TaggedDocument(words=['Kim', 'Jong', 'Un', '’', 'sister', 'reportedly', 'gaining', 'power', 'North', 'Korea'], tags=['SENT_961']),
#  TaggedDocument(words=['Teenager', "'who", 'spat', 'bus', 'driver', 'coronavirus', 'lockdown', 'arrested'], tags=['SENT_962']),
#  TaggedDocument(words=['Morocco', 'Literacy', 'rate'], tags=['SENT_963']),
#  TaggedDocument(words=['Captain', 'Tom', 'Moore', "'s", 'NHS', 'appeal', 'tops', '£31m', '100th', 'birthday'], tags=['SENT_964']),
#  TaggedDocument(words=['Survey', 'Finds', 'Working', 'From', 'Home', 'Has', 'So', 'Many', 'Benefits', '48', 'Workers', 'Would', 'Take', 'Pay', 'Cut', 'Continue'], tags=['SENT_965']),
#  TaggedDocument(words=['Coronavirus', '50', 'corpses', 'discovered', 'US', 'trucks', 'neighbours', 'noticed', 'smell', 'leaks'], tags=['SENT_966']),
#  TaggedDocument(words=['Coronavirus', 'WHO', "'not", 'invited', 'join', 'China', "'s", 'COVID-19', 'investigations'], tags=['SENT_967']),
#  TaggedDocument(words=['Japanese', 'city', 'cuts', '800,000', 'tulips', 'visitors', 'refuse', 'stay', 'away', 'cancelled', 'flower', 'festival'], tags=['SENT_968']),
#  TaggedDocument(words=['Israel', '’', 'Largest', 'Bank', 'Bank', 'Hapoalim', 'Admits', 'Conspiring', 'U.S.', 'Taxpayers', 'Hide', 'Assets', 'Income', 'Offshore', 'Accounts'], tags=['SENT_969']),
#  TaggedDocument(words=['Canada', "'s", 'early', 'COVID-19', 'cases', 'came', 'U.S.', 'China', 'provincial', 'data', 'shows'], tags=['SENT_970']),
#  TaggedDocument(words=['Special', 'Report', 'Trump', 'told', 'Saudi', 'Cut', 'oil', 'supply', 'lose', 'U.S.', 'military', 'support', 'sources'], tags=['SENT_971']),
#  TaggedDocument(words=['Greenhouse', 'Gas', 'Emissions', 'Predicted', 'To', 'Fall', 'Nearly', '8', '—', 'Largest', 'Decrease', 'Ever'], tags=['SENT_972']),
#  TaggedDocument(words=['In', 'Victory', 'Women', 'Sudan', 'Female', 'Genital', 'Mutilation', 'Is', 'Outlawed'], tags=['SENT_973']),
#  TaggedDocument(words=['Australia', 'back', 'Taiwan', "'s", 'return', 'WHO'], tags=['SENT_974']),
#  TaggedDocument(words=['New', 'Study', 'Reveals', 'That', '81', 'World', 'Population', 'Is', 'Calling', 'Upon', 'Billionaires', 'Contribute', 'More', 'Charity', '–', 'Especially', 'During', 'COVID-19', 'Pandemic', '–', 'Press', 'Releases', 'CSRwire.com'], tags=['SENT_975']),
#  TaggedDocument(words=['Taiwan', 'rejoining', 'World', 'Health', 'Organization', 'still', 'backed', 'Australia', 'diplomatically', 'risky', 'move'], tags=['SENT_976']),
#  TaggedDocument(words=['Xiaomi', 'Devices', 'Found', 'Tracking', 'And', 'Recording', 'Browsing', 'Data', 'Of', 'Millions'], tags=['SENT_977']),
#  TaggedDocument(words=['China', 'Warns', 'Australia', 'It', 'Could', 'Face', 'Boycotts', 'Over', 'Call', 'Independent', 'Inquiry', 'Into', 'Coronavirus'], tags=['SENT_978']),
#  TaggedDocument(words=['LED', 'lights', 'halve', 'unwanted', 'fish', 'nets', 'research', 'finds'], tags=['SENT_979']),
#  TaggedDocument(words=['EU', 'chief', 'backs', 'investigation', 'coronavirus', 'origin', 'says', 'China', 'involved'], tags=['SENT_980']),
#  TaggedDocument(words=['Japanese', 'island', 'suffering', 'second', 'wave', 'coronavirus', 'lifting', 'lockdown', 'early'], tags=['SENT_981']),
#  TaggedDocument(words=['Chinese', 'journalist', 'jailed', 'criticising', 'Communist', 'Party'], tags=['SENT_982']),
#  TaggedDocument(words=['Coronavirus', 'David', 'Icke', 'kicked', 'Facebook'], tags=['SENT_983']),
#  TaggedDocument(words=['Trudeau', 'announces', 'ban', '1,500', 'types', "'assault-style", 'firearms', '—', 'effective', 'immediately'], tags=['SENT_984']),
#  TaggedDocument(words=['Four-in-five', 'Canadians', 'support', 'complete', 'ban', 'civilian', 'possession', 'assault', 'style', 'weapons'], tags=['SENT_985']),
#  TaggedDocument(words=['Canada', 'bans', 'assault', 'weapons', 'following', 'worst-ever', 'mass', 'shooting'], tags=['SENT_986']),
#  TaggedDocument(words=['New', 'report', 'says', 'coronavirus', 'pandemic', 'could', 'last', 'two', 'years', '–', 'may', 'subside', '70', 'population', 'immunity'], tags=['SENT_987']),
#  TaggedDocument(words=['Lawmakers', 'demand', 'Jeff', 'Bezos', 'testify', 'Amazon', "'s", 'alleged', 'misuse', 'data'], tags=['SENT_988']),
#  TaggedDocument(words=['Imported', 'rich', 'coronavirus', 'devastating', 'Brazil', "'s", 'poor'], tags=['SENT_989']),
#  TaggedDocument(words=['President', "'s", "'So", '5,000', 'die', 'sparks', 'fury', 'Brazil'], tags=['SENT_990']),
#  TaggedDocument(words=['Japanese', 'aquarium', 'urges', 'public', 'video-chat', 'eels', 'forgetting', 'humans', 'exist'], tags=['SENT_991']),
#  TaggedDocument(words=['Thailand', "'s", 'king', 'living', 'luxury', 'quarantine', 'country', 'suffers'], tags=['SENT_992']),
#  TaggedDocument(words=['Coronavirus', 'NSW', 'Dossier', 'lays', 'case', 'China', 'bat', 'virus', 'program'], tags=['SENT_993']),
#  TaggedDocument(words=['Earth', "'s", 'Insect', 'Population', 'Shrunk', '‘', 'Jaw-Dropping', '’', '27', 'Over', 'Past', '30', 'Years'], tags=['SENT_994']),
#  TaggedDocument(words=['Putin', 'critic', 'vows', '‘', 'tell', 'truth', '’', 'COVID-19', 'crisis', 'Russia', 'despite', 'threats', 'life'], tags=['SENT_995']),
#  TaggedDocument(words=['Coronavirus', 'Amazon', 'deforestation', 'could', 'trigger', 'new', 'pandemics', 'experts', 'warn', 'amid', 'fears', 'Brazilian', 'land', 'ownership', 'law'], tags=['SENT_996']),
#  TaggedDocument(words=['Fire', 'attacks', 'Scottish', 'phone', 'masts', 'soar', 'bogus', '5G', 'coronavirus', 'conspiracy', 'theory', 'spreads'], tags=['SENT_997']),
#  TaggedDocument(words=['Pope', "'s", "'Robin", 'Hood', 'Wired', 'Money', 'For', 'Food', 'To', 'Struggling', 'Transgender', 'Sex', 'Workers'], tags=['SENT_998']),
#  TaggedDocument(words=['Russia', 'sees', 'record', 'spike', 'coronavirus', 'cases', 'nearly', '10,000', 'one', 'day'], tags=['SENT_999']),
#  ...]

# %% [markdown]
# ### Pickle the tag_lookup dictionary so I can load it later in my data app

# %%
with open('models/doc2vec/tag_lookup.pickle', 'wb') as f:
    pickle.dump(tag_lookup, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Build and train a Doc2Vec model

# %%
model = Doc2Vec(alpha=0.025, min_alpha=0.025)
model.build_vocab(sentences)
model.train(sentences, total_examples=len(sentences), epochs=100)

# %% [markdown]
# ### The next step is to lookup a headline, find similar headlines, and compare the sentiment of that headline to other similar headlines.

# %%
# function to lookup a headline and find similar headlines
def find_similar(headline, topn):
    new_clean_headline = clean_headline(headline)
    similar = model.docvecs.most_similar(positive=[model.infer_vector(new_clean_headline)],topn=topn)

    return similar

# %% [markdown]
# ### Test the model on a headline not included in the training set

# %%
new_headline = 'this is a test headline, this is not real'
similar = find_similar(new_headline, 5)

print(f'{new_headline}')
blob = TextBlob(new_headline)
print(blob.sentiment)
print()

# show similar headlines
for i, s in enumerate(similar):
    print(f'{i}: {tag_lookup[s[0]]} -- {TextBlob(tag_lookup[s[0]]).sentiment}')
# Out:
# this is a test headline, this is not real
# Sentiment(polarity=-0.1, subjectivity=0.30000000000000004)
#
# 0: Hackers post fake stories on real news sites 'to discredit Nato' -- Sentiment(polarity=-0.15, subjectivity=0.65)
# 1: Conservative delegates reject adding 'climate change is real' to the policy book -- Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# 2: Cancer can be precisely diagnosed using a urine test with artificial intelligence -- Sentiment(polarity=-0.09999999999999998, subjectivity=0.9)
# 3: CERN scientists design trap to transport antimatter between facilities -- Sentiment(polarity=0.0, subjectivity=0.0)
# 4: Breakthrough mRNA vaccine developed for cancer immunotherapy by Chinese scientists -- Sentiment(polarity=0.05, subjectivity=0.15)

# %% [markdown]
# ### Lookup an existing headline to see other similar headlines
# Since the headline I'm looking up was part of training, the most similar headline is always the same one I looked up. So to get the top 5 most similar headlines, I just get the top 6 and ignore the first.

# %%
new_headline = df['headline'][0]
similar = find_similar(new_headline, 6)
similar.pop(0)

print(f'{new_headline}')
blob = TextBlob(new_headline)
print(blob.sentiment)
print()

# show similar headlines
for i, s in enumerate(similar):
    print(f'{i}: {tag_lookup[s[0]]} -- {TextBlob(tag_lookup[s[0]]).sentiment}')
# Out:
# Muons: 'Strong' evidence found for a new force of nature
# Sentiment(polarity=0.2848484848484848, subjectivity=0.5939393939393939)
#
# 0: Israel keeps blowing up military targets in Iran, hoping to force a confrontation before Trump can be voted out in November, sources say -- Sentiment(polarity=-0.1, subjectivity=0.1)
# 1: Legislation coming this year to force Google, Facebook to pay for news content -- Sentiment(polarity=0.0, subjectivity=0.0)
# 2: WHO acknowledges 'emerging evidence' of airborne spread of COVID-19 -- Sentiment(polarity=0.0, subjectivity=0.0)
# 3: Taiwan produces evidence it warned WHO of coronavirus in December -- Sentiment(polarity=0.0, subjectivity=0.0)
# 4: Taiwan reports large incursion by Chinese air force -- Sentiment(polarity=0.10714285714285714, subjectivity=0.21428571428571427)

# %% [markdown]
# ### Presenting the results
# I figured the best way to present these results would be a data app. This way a user can select whatever headline they want and find similar ones. To do this, I will save the Doc2Vec model to a file and load it from the app.

# %%
model.save('models/doc2vec/headline_model')

# %% [markdown]
# Test loading the model to make sure it works

# %%
loaded_model = Doc2Vec.load('headline_model')

new_headline = df['headline'][1]
new_clean_headline = clean_headline(new_headline)
similar = loaded_model.docvecs.most_similar(positive=[model.infer_vector(new_clean_headline)],topn=6)
similar.pop(0)

print(f'{new_headline}')
blob = TextBlob(new_headline)
print(blob.sentiment)
print()

# show similar headlines
for i, s in enumerate(similar):
    print(f'{i}: {tag_lookup[s[0]]} -- {TextBlob(tag_lookup[s[0]]).sentiment}')
# Out:
# A third of COVID survivors suffer neurological or mental disorders: study
# Sentiment(polarity=-0.05, subjectivity=0.1)
#
# 0: Dark hair was common among Vikings, genetic study confirms -- Sentiment(polarity=-0.22499999999999998, subjectivity=0.45)
# 1: Saudi Arabia textbooks revised to be more tolerant - study -- Sentiment(polarity=0.5, subjectivity=0.5)
# 2: Nurses suffer burn-out, psychological distress in COVID fight - association -- Sentiment(polarity=0.0, subjectivity=0.1)
# 3: Billionaire Kerry Stokes exempted from strict quarantine rules after arriving in Perth from Aspen by private jet -- Sentiment(polarity=0.0, subjectivity=0.375)
# 4: A 64-year-old man accidentally ejected himself from a fighter jet at 2,500 feet -- Sentiment(polarity=0.0, subjectivity=0.0)
